# %%
import pandas as pd
from ekonlpy.sentiment import MPCK
from nltk.corpus import stopwords

def text2ngram(text):
    mpck = MPCK()
    bef_tokens = mpck.tokenize(text)
    return bef_tokens
stop_words = ['NR',
 'VX',
 'VCP',
 'VCN',
 'MM',
 'MAJ',
 'IC',
 'JKS',
 'JKC',
 'JKG',
 'JKO',
 'JKB',
 'JKV',
 'JKQ',
 'JX',
 'JC',
 'EP',
 'EF',
 'EC',
 'ETN',
 'ETM',
 'XPN',
 'XSN',
 'XSV',
 'XSA',
 'XR',
 'SF',
 'SE',
 'SSO',
 'SSC',
 'SC',
 'SY',
 'SL',
 'SH',
 'SN',
'NNG',
             'VV']

result = []
text = file_copy.text[:2]
token_list = []
for i in text:
    
    for token in text2ngram(i):#word_Token
        
        token_list.append(token)
        if token.split('/')[1] not in stop_words:
            result.append(token)
result
