# %%
import pandas as pd
file = pd.read_csv('2005-2017_news_data_final.csv')
# Out:
# C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
file_copy = file.copy()

# %%
for idx, date in enumerate(file_copy.date):

    if '2018' in date:
        print(idx)
        file_copy.drop(idx, axis = 0,  inplace = True)
# Out:
# 232662
# 232663
# 232664
# 232665
# 232666
# 232667
# 232678
# 232679
# 232680
# 232681
# 232682
# 232683
# 232685
# 232686
# 232805
# 232806
# 232807
# 232808
# 232810
# 232811
# 232813
# 232814
# 232815
# 232816
# 232817
# 232818
# 232819
# 232820
# 232821
# 232822
# 232823
# 232824
# 232825
# 232826
# 232827
# 232828
# 232829
# 232830
# 232831
# 232832
# 232833
# 232834
# 232835
# 232836
# 232837
# 232838
# 232839
# 232840
# 232841
# 232842
# 232843
# 232844
# 232845
# 232846
# 232847
# 232848
# 232849
# 232850
# 232851
# 232852
# 232853
# 232854
# 232855
# 232856
# 232857
# 232858
# 232859
# 232860
# 232861
# 232862

# %%
file_copy.loc[file_copy['date'] == "2018.01.02"].head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, date, news_media, text, title, url, ngrams]
# Index: []

# %%
file_copy.drop('level_0', axis= 1, inplace = True)
file_copy
# Out:
#               date news_media  \
# 0       2006.01.09     연합인포맥스
# 1       2006.01.03     연합인포맥스
# 2       2006.01.23     연합인포맥스
# 3       2006.01.23     연합인포맥스
# 4       2006.01.24     연합인포맥스
# 5       2006.01.13     연합인포맥스
# 6       2006.01.03     연합인포맥스
# 7       2006.01.23     연합인포맥스
# 8       2006.01.23     연합인포맥스
# 9       2006.01.13     연합인포맥스
# 10      2006.01.13     연합인포맥스
# 11      2006.01.17     연합인포맥스
# 12      2006.01.17     연합인포맥스
# 13      2006.01.13     연합인포맥스
# 14      2006.01.13     연합인포맥스
# 15      2006.01.24     연합인포맥스
# 16      2006.01.17     연합인포맥스
# 17      2006.01.13     연합인포맥스
# 18      2006.01.23     연합인포맥스
# 19      2006.01.23     연합인포맥스
# 20      2006.01.17     연합인포맥스
# 21      2006.01.24     연합인포맥스
# 22      2006.01.13     연합인포맥스
# 23      2006.01.13     연합인포맥스
# 24      2006.01.23     연합인포맥스
# 25      2006.01.24     연합인포맥스
# 26      2006.01.23     연합인포맥스
# 27      2006.01.23     연합인포맥스
# 28      2006.01.23     연합인포맥스
# 29      2006.01.17     연합인포맥스
# ...

# %%
file_copy.reset_index(inplace=True)
