# %% [markdown]
# # csv합치기

# %%
import pandas as pd
import glob

file1 = 'newsdata_2005-2017.csv'
file2 = 'newsinfo.csv'

file1_csv = pd.read_csv(file1)
file2_csv = pd.read_csv(file2)

# %%
import pandas as pd

file1_csv = pd.read_csv('news_final.csv')
file1_csv
# Out:
#         Unnamed: 0         date news_media  \
# 0                0  2006.01.11.       연합뉴스
# 1                1  2006.01.06.       연합뉴스
# 2                2  2006.01.06.       연합뉴스
# 3                3  2006.01.06.       연합뉴스
# 4                4  2006.01.11.       연합뉴스
# 5                5  2006.01.05.       연합뉴스
# 6                6  2006.01.05.       연합뉴스
# 7                7  2006.01.11.       연합뉴스
# 8                8  2006.01.05.       연합뉴스
# 9                9  2006.01.11.       연합뉴스
# 10              10  2006.01.05.       연합뉴스
# 11              11  2006.01.11.       연합뉴스
# 12              12  2006.01.13.       연합뉴스
# 13              13  2006.01.05.       연합뉴스
# 14              14  2006.01.11.       연합뉴스
# 15              15  2006.01.06.       연합뉴스
# 16              16  2006.01.06.       연합뉴스
# 17              17  2006.01.05.       연합뉴스
# 18              18  2006.01.11.       연합뉴스
# 19              19  2006.01.05.       연합뉴스
# 20              20  2006.01.05.       연합뉴스
# ...

# %%
file1_csv = file1_csv.drop(file1_csv['date'] == '2018', axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-521c17042011> in <module>
# ----> 1 file1_csv = file1_csv.drop(file1_csv['date'] == '2018', axis = 0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
file1_csv = file1_csv.rename(columns ={'content':'text'})

# %%
file1_csv.to_csv('final_news_data.csv')

# %%
file2_csv['news_media'] = '연합인포멕스'
file2_csv
# Out:
#               date                                  title  \
# 0       2019.07.09       월가 "도이체 1만8천명 감원 불충분"…추가 구조조정 예상
# 1       2019.07.10        [서환-마감] 파월 연설 대기 속 역외 매수…1.10원↑
# 2       2019.07.10         필라델피아 연은 총재 "금리 변경할 긴박한 필요 없어"
# 3       2019.07.12                   [오늘의 주요 국제금융뉴스](12일)
# 4       2019.07.12        <전소영의 채권분석> 인하하면 반등할까, 안 하면 어쩌나
# 5       2019.07.10            'FX 스와프 떨어진다'…보험사 에셋 물량 몰릴까
# 6       2019.07.06                   딜링룸 24시…챙겨봐야할 국제경제뉴스
# 7       2019.07.05              호주 재무장관 "美·中 무역분쟁, 오래갈 것"
# 8       2019.07.04                     FX스와프, 뉴욕 휴장 속 보합권
# 9       2019.07.04         [채권-마감] 금리 연저점 갱신…부총리 폴리시믹스 발언
# 10      2019.07.03      [채권-마감] 금리 대내외 롱재료에 급락…3년물 연저점 근접
# 11      2019.07.06    <뉴욕마켓워치> 고용 호조 금리인하 기대 약화…주가·국채↓달러↑
# 12      2019.07.06         NDF, 1,174.10/1,174.30원…4.70원↑
# 13      2019.07.07  <뉴욕증시 주간전망> 파월 증언과 FOMC 의사록…연준에 시선 집중
# 14      2019.07.06                     [오늘 기재부 등 경제부처 일정]
# ...

# %%
#full_df = pd.concat([file1_csv, file2_csv], ignore_index = True)
full_df[180000:182000]

# %%
full_df
# Out:
#         Unnamed: 0  Unnamed: 0.1         date news_media  \
# 0              0.0           NaN  2006.01.11.   ['연합뉴스']
# 1              1.0           NaN  2006.01.06.   ['연합뉴스']
# 2              2.0           NaN  2006.01.06.   ['연합뉴스']
# 3              3.0           NaN  2006.01.06.   ['연합뉴스']
# 4              4.0           NaN  2006.01.11.   ['연합뉴스']
# 5              5.0           NaN  2006.01.05.   ['연합뉴스']
# 6              6.0           NaN  2006.01.05.   ['연합뉴스']
# 7              7.0           NaN  2006.01.11.   ['연합뉴스']
# 8              8.0           NaN  2006.01.05.   ['연합뉴스']
# 9              9.0           NaN  2006.01.11.   ['연합뉴스']
# 10            10.0           NaN  2006.01.05.   ['연합뉴스']
# 11            11.0           NaN  2006.01.11.   ['연합뉴스']
# 12            12.0           NaN  2006.01.13.   ['연합뉴스']
# 13            13.0           NaN  2006.01.05.   ['연합뉴스']
# 14            14.0           NaN  2006.01.11.   ['연합뉴스']
# ...

# %% [markdown]
# # df 저장

# %%
full_df.to_csv('output_newsdata.csv')

# %% [markdown]
# # csv확인

# %%
full_df
# Out:
#                date news_media  \
# 0       2006.01.11.   ['연합뉴스']
# 1       2006.01.06.   ['연합뉴스']
# 2       2006.01.06.   ['연합뉴스']
# 3       2006.01.06.   ['연합뉴스']
# 4       2006.01.11.   ['연합뉴스']
# 5       2006.01.05.   ['연합뉴스']
# 6       2006.01.05.   ['연합뉴스']
# 7       2006.01.11.   ['연합뉴스']
# 8       2006.01.05.   ['연합뉴스']
# 9       2006.01.11.   ['연합뉴스']
# 10      2006.01.05.   ['연합뉴스']
# 11      2006.01.11.   ['연합뉴스']
# 12      2006.01.13.   ['연합뉴스']
# 13      2006.01.05.   ['연합뉴스']
# 14      2006.01.11.   ['연합뉴스']
# 15      2006.01.06.   ['연합뉴스']
# 16      2006.01.06.   ['연합뉴스']
# 17      2006.01.05.   ['연합뉴스']
# 18      2006.01.11.   ['연합뉴스']
# 19      2006.01.05.   ['연합뉴스']
# 20      2006.01.05.   ['연합뉴스']
# 21      2006.01.13.   ['연합뉴스']
# 22      2006.01.13.   ['연합뉴스']
# 23      2006.01.11.   ['연합뉴스']
# 24      2006.01.11.   ['연합뉴스']
# 25      2006.01.05.   ['연합뉴스']
# 26      2006.01.11.   ['연합뉴스']
# 27      2006.01.06.   ['연합뉴스']
# 28      2006.01.13.   ['연합뉴스']
# ...

# %% [markdown]
# # 데이터 다듬기

# %%
#full_df = full_df.drop('Unnamed: 0',axis =1)

full_df.text = full_df.text.str.replace('()', '')
#full_df_copy = full_df.copy()
full_df
# Out:
#                date news_media  \
# 0       2006.01.11.       연합뉴스
# 1       2006.01.06.       연합뉴스
# 2       2006.01.06.       연합뉴스
# 3       2006.01.06.       연합뉴스
# 4       2006.01.11.       연합뉴스
# 5       2006.01.05.       연합뉴스
# 6       2006.01.05.       연합뉴스
# 7       2006.01.11.       연합뉴스
# 8       2006.01.05.       연합뉴스
# 9       2006.01.11.       연합뉴스
# 10      2006.01.05.       연합뉴스
# 11      2006.01.11.       연합뉴스
# 12      2006.01.13.       연합뉴스
# 13      2006.01.05.       연합뉴스
# 14      2006.01.11.       연합뉴스
# 15      2006.01.06.       연합뉴스
# 16      2006.01.06.       연합뉴스
# 17      2006.01.05.       연합뉴스
# 18      2006.01.11.       연합뉴스
# 19      2006.01.05.       연합뉴스
# 20      2006.01.05.       연합뉴스
# 21      2006.01.13.       연합뉴스
# 22      2006.01.13.       연합뉴스
# 23      2006.01.11.       연합뉴스
# 24      2006.01.11.       연합뉴스
# 25      2006.01.05.       연합뉴스
# 26      2006.01.11.       연합뉴스
# 27      2006.01.06.       연합뉴스
# 28      2006.01.13.       연합뉴스
# ...

# %%
#full_df_copy.news_media = full_df_copy.news_media.str.replace("]", '')
full_df.to_csv("news_final.csv", encoding = 'UTF8')

# %%
my_csv_in = r'full_file_path_to_csv_out.csv'
#r'fallthree(without_einfomax).csv'
#r'full_file_path_to_csv_out.csv'
my_csv_out = r'fallthree(without_einfomax).csv'

with open(my_csv_in, 'rt', encoding = 'UTF8') as f_in:
    with open(my_csv_out, 'wt',encoding = 'UTF8') as f_out:
        for line in f_in:
            f_out.write(line.replace("']", ''))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-165-7a33895d72df> in <module>
#       4 my_csv_out = r'fallthree(without_einfomax).csv'
#       5
# ----> 6 with open(my_csv_in, 'rt', encoding = 'UTF8') as f_in:
#       7     with open(my_csv_out, 'wt',encoding = 'UTF8') as f_out:
#       8         for line in f_in:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'full_file_path_to_csv_out.csv'

# %%
all_three = pd.read_csv('fallthree(without_einfomax).csv')
all_three.to_csv('final_newsdata.csv', mode= 'wt', encoding = 'UTF8')

# %%
data = pd.read_csv('final_newsdata.csv')
# Out:
# C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 0.1         date news_media  \
# 0           0             0  2006.01.11.       연합뉴스
# 1           1             1  2006.01.06.       연합뉴스
# 2           2             2  2006.01.06.       연합뉴스
# 3           3             3  2006.01.06.       연합뉴스
# 4           4             4  2006.01.11.       연합뉴스
#
#                                                 text  \
# 0   11개 기관 인수단으로 선정 (서울=연합뉴스) 이 율 기자 = 국고채 20년물의 ...
# 1   (서울=연합뉴스) 윤근영 이 율 기자= 외환당국이 6일 환율급락을 막기 위해 강력...
# 2   (서울=연합뉴스) 추승호 기자 = 우리은행은 6일 주가가 상승하면 추가수익을 얻을...
# 3   中, 美국채매입 축소 시사 (서울=연합뉴스) 위안(元) 평가절상을 노리고 지난 몇...
# 4   (서울=연합뉴스) 권영석 기자 = 씨티그룹은 11일 미국 달러화 약세와 한국 외환...
#
#                                title  \
# ...

# %%
data.drop(['Unnamed: 0', 'Unnamed: 0.1', 'news_media'], axis = 1, inplace = True)
data.head()
# Out:
#           date                                               text  \
# 0  2006.01.11.   11개 기관 인수단으로 선정 (서울=연합뉴스) 이 율 기자 = 국고채 20년물의 ...
# 1  2006.01.06.   (서울=연합뉴스) 윤근영 이 율 기자= 외환당국이 6일 환율급락을 막기 위해 강력...
# 2  2006.01.06.   (서울=연합뉴스) 추승호 기자 = 우리은행은 6일 주가가 상승하면 추가수익을 얻을...
# 3  2006.01.06.   中, 美국채매입 축소 시사 (서울=연합뉴스) 위안(元) 평가절상을 노리고 지난 몇...
# 4  2006.01.11.   (서울=연합뉴스) 권영석 기자 = 씨티그룹은 11일 미국 달러화 약세와 한국 외환...
#
#                                title  \
# 0  국고채 20년물 금리 `10년물+0.21~0.30%'(종합)
# 1                 환율 안정대책 실효성 있나(종합)
# 2                   우리은행 '운수대통 복합예금'
# 3                         위안 투기자본 철수
# 4            원.달러 환율 1년 안에 920원까지 하락
#
#                                                  url
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
import pandas as pd

data = pd.read_csv('real_final_newsdata.csv')

# %% [markdown]
# # 날짜 바꾸기

# %%
file1_csv['date'] = file1_csv['date'].str[:4] + '.' + file1_csv['date'].str[5:7] + '.' + file1_csv['date'].str[8:10]

# %%
file1_csv
# Out:
#         Unnamed: 0        date news_media  \
# 0                0  2006.01.11       연합뉴스
# 1                1  2006.01.06       연합뉴스
# 2                2  2006.01.06       연합뉴스
# 3                3  2006.01.06       연합뉴스
# 4                4  2006.01.11       연합뉴스
# 5                5  2006.01.05       연합뉴스
# 6                6  2006.01.05       연합뉴스
# 7                7  2006.01.11       연합뉴스
# 8                8  2006.01.05       연합뉴스
# 9                9  2006.01.11       연합뉴스
# 10              10  2006.01.05       연합뉴스
# 11              11  2006.01.11       연합뉴스
# 12              12  2006.01.13       연합뉴스
# 13              13  2006.01.05       연합뉴스
# 14              14  2006.01.11       연합뉴스
# 15              15  2006.01.06       연합뉴스
# 16              16  2006.01.06       연합뉴스
# 17              17  2006.01.05       연합뉴스
# 18              18  2006.01.11       연합뉴스
# 19              19  2006.01.05       연합뉴스
# 20              20  2006.01.05       연합뉴스
# ...

# %%
import pandas as pd

file1 = pd.read_csv('news2006-2010.csv')
file2 = pd.read_csv('final_news_data_mecab_added.csv')


added = pd.concat([file1, file2], ignore_index = True)

added
# Out:
# C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1        date  \
# 0                0           NaN             NaN  2006.01.09
# 1                1           NaN             NaN  2006.01.03
# 2                2           NaN             NaN  2006.01.23
# 3                3           NaN             NaN  2006.01.23
# 4                4           NaN             NaN  2006.01.24
# 5                5           NaN             NaN  2006.01.13
# 6                6           NaN             NaN  2006.01.03
# 7                7           NaN             NaN  2006.01.23
# 8                8           NaN             NaN  2006.01.23
# ...

# %%
added.to_csv('2005-2017_news_data_final.csv')

# %%
added.to_csv('2005-2017_news_data_final.csv')
