# %%
import os
import pandas as pd
import xlrd
from datetime import timedelta, date 
import datetime

# %%
BASE_DIR = os.getcwd()   #현재 경로 탐색
DATASET_PATH = os.path.join(BASE_DIR, "call.xlsx")   #path 연결
df = pd.read_excel('call.xlsx',index_col='date')   #xlsx파일 DataFrame으로 변환

# %%
df.index = pd.to_datetime(df.index)   # index type -> datetime타입으로 변경
df['updown'] = None   #'updown'칼럼 추가

# %%
i = 0
for day in df.index:
    ago = day - pd.DateOffset(months=1)
    
    while ago not in df.index:
        ago = ago - timedelta(1)
        
    if df.loc[day]['price'] < df.loc[ago]['price']:
        df['updown'][i] = '하락'
    elif df.loc[day]['price'] == df.loc[ago]['price']:
        df['updown'][i] = 0
    else:
        df['updown'][i] = '상승'
        
    i += 1
    if i % 10 == 0:
        print(i,"번째 입니다")
        
    if datetime.date(2005,1,3) == day.date():
        break
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# 10 번째 입니다
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# 20 번째 입니다
# ...

# %%
df_new = df.loc[:'2005-01-03']

# %%
df_new.to_csv("test.csv")

# %%
pd.read_csv('test.csv')
# Out:
#             date  price updown
# 0     2019-07-15   1.73     하락
# 1     2019-07-12   1.74     하락
# 2     2019-07-11   1.75      0
# 3     2019-07-10   1.74     하락
# 4     2019-07-09   1.69     하락
# 5     2019-07-08   1.73     하락
# 6     2019-07-05   1.73      0
# 7     2019-07-04   1.73     하락
# 8     2019-07-03   1.73     하락
# 9     2019-07-02   1.73     하락
# 10    2019-07-01   1.75     하락
# 11    2019-06-28   1.83     상승
# 12    2019-06-27   1.77     상승
# 13    2019-06-26   1.76     상승
# 14    2019-06-25   1.75     상승
# 15    2019-06-24   1.75     상승
# 16    2019-06-21   1.74     상승
# 17    2019-06-20   1.75     하락
# 18    2019-06-19   1.76     상승
# 19    2019-06-18   1.75     상승
# 20    2019-06-17   1.76     상승
# 21    2019-06-14   1.74     상승
# 22    2019-06-13   1.75      0
# 23    2019-06-12   1.75     상승
# 24    2019-06-11   1.75     상승
# 25    2019-06-10   1.75     상승
# 26    2019-06-07   1.77     상승
# 27    2019-06-05   1.73     하락
# 28    2019-06-04   1.75     상승
# ...
