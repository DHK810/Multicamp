# %%
import pandas as pd

data = pd.read_csv('output.csv')

data
# Out:
#         Unnamed: 0        asin                                 item_model_no  \
# 0                0  B07S1HTSGH                                           NaN
# 1                1  B07S1HTSGH                                           NaN
# 2                2  B07S1HTSGH                                           NaN
# 3                3  B07S1HTSGH                                           NaN
# 4                4  B07S1HTSGH                                           NaN
# 5                5  B07S1HTSGH                                           NaN
# 6                6  B07S1HTSGH                                           NaN
# 7                7  B07S1HTSGH                                           NaN
# 8                8  B07S1HTSGH                                           NaN
# 9                9  B07S1HTSGH                                           NaN
# 10              10  B079GDB7C7                                           NaN
# ...

# %%
KW = ['outperform', 'choose', 'prefer', 'exceed']
df = data[data.review.str.contains('outperform|choose|prefer|exceed')== True]

# %%
df = df.reset_index()

# %%
df.loc[30, 'review']
# Out:
# 'This camera has exceeded expectations. Due to its size, features and ease of use it was perfect for our trip to Disney World.'
