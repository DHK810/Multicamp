# %%
import pandas as pd

test_data = pd.read_csv(r'C:\Users\15Z970-GA5BK\Desktop\multicampus0724\DH practice\ML\test.csv')
train_data = pd.read_csv(r'C:\Users\15Z970-GA5BK\Desktop\multicampus0724\DH practice\ML\train.csv')
# Out:
#               asin         date     product  \
# 0       B00000JFOA   01 6, 2000      c-2000
# 1       B000023VQC  06 24, 2001     pdc-700
# 2       B00003OPEY  04 26, 2000    dsc-f505
# 3       B00004R8V6   09 5, 2000      d-360l
# 4       B00004R8VC  04 18, 2000       d-460
# 5       B00004R8VC  04 19, 2000       d-460
# 6       B00004R8VC  09 14, 2000       d-460
# 7       B00004R8VE  12 29, 2013       c3030
# 8       B00004R8VE  05 26, 2001       c3030
# 9       B00004R8VE  06 10, 2000       c3030
# 10      B00004SV1W  05 14, 2001    qv3000ex
# 11      B00004SV1W  11 25, 2000    qv3000ex
# 12      B00004SYN1  12 12, 2000         s10
# 13      B00004SYN1  05 22, 2001         s10
# 14      B00004TBDY  10 18, 2000     pdr-m60
# 15      B00004TCTK  05 15, 2000         s20
# 16      B00004TCWL   10 2, 2004     cds4100
# 17      B00004TH2X  05 19, 2001        4700
# 18      B00004TH2X  11 14, 2000        4700
# 19      B00004TJ7O   01 5, 2006      c-3000
# 20      B00004TJ7O  12 29, 2013      c-3000
# 21      B00004TJ7O   10 5, 2001      c-3000
# 22      B00004TJ7O  12 14, 2000      c-3000
# 23      B00004TKHW  12 28, 2000     mvcfd85
# 24      B00004TS16  12 28, 2000        s100
# 25      B00004TS16  11 14, 2000        s100
# 26      B00004TS16  12 21, 2001        s100
# 27      B00004TS16  06 16, 2001        s100
# 28      B00004TS16  12 29, 2000        s100
# 29      B00004TS16   01 8, 2001        s100
# ...            ...          ...         ...
# 165724  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165725  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165726  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165727  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165728  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165729  B00K7O2DJU   07 3, 2014  dsc-rx100m
# 165730  B00K7O2DJU   07 3, 2014  dsc-rx100m
# 165731  B00K7O2DJU   07 3, 2014  dsc-rx100m
# 165732  B00K7O2DJU   07 3, 2014  dsc-rx100m
# 165733  B00K7O2DJU   07 3, 2014  dsc-rx100m
# 165734  B00K7O2DJU   07 3, 2014  dsc-rx100m
# 165735  B00K7O2DJU   07 3, 2014  dsc-rx100m
# 165736  B00K7O2DJU  06 30, 2014  dsc-rx100m
# 165737  B00K7O2DJU  06 30, 2014  dsc-rx100m
# 165738  B00K7O2DJU  06 25, 2014  dsc-rx100m
# 165739  B00K7O2DJU  06 21, 2014  dsc-rx100m
# 165740  B00K7O2DJU  07 20, 2014  dsc-rx100m
# 165741  B00K7O2DJU   07 5, 2014  dsc-rx100m
# 165742  B00K7O2DJU   07 5, 2014  dsc-rx100m
# 165743  B00K7O2DJU   07 5, 2014  dsc-rx100m
# 165744  B00K7O2DJU   07 5, 2014  dsc-rx100m
# 165745  B00K7O2DJU   07 5, 2014  dsc-rx100m
# 165746  B00K7O2DJU  07 12, 2014  dsc-rx100m
# 165747  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165748  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165749  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165750  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165751  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165752  B00K7O2DJU  06 20, 2014  dsc-rx100m
# 165753  B00K7O2DJU  06 20, 2014  dsc-rx100m
#
#                                                    review  score  \
# 0       the  newer model c-2020 has all the fixes exce...    4.0
# 1       it likes to change from xga to vga etc.. *the ...    2.0
# 2       the included memory stick is a  little small b...    5.0
# 3       it also  adds a nifty little optical function ...    5.0
# 4       i read a lot of reviews on the d450 optical be...    5.0
# 5       under the d450 reviews, several users recommen...    5.0
# 6       the new cmos  technology is suppose to yield p...    5.0
# 7       made  over 200,000 photos with it ... this  ca...    5.0
# 8       my next purchase is the wide-angle lens.i boug...    5.0
# 9       if  you are willing to trade off a sflashly sm...    5.0
# 10      otherwise i'm going to have to take up my frie...    3.0
# 11      when i started research 3.x gigapixel digital ...    5.0
# 12      the s20 may even be worth the extra for the hi...    5.0
# 13      the reason i would choose s10 over s100 or oth...    5.0
# 14      additionally, the included toshiba software ca...    4.0
# 15      the camera is  small and flashweight.. similar...    5.0
# 16      i have one of these camera's also rca cds4100....    1.0
# 17      canon has only 2x (although in japan i have no...    4.0
# 18      otherwise i would have told my parents to get ...    3.0
# 19      i think the only thing i regret is that it doe...    5.0
# 20      made over 200,000 photos with it ... this came...    5.0
# 21      aluminum casting!a few features that i wish it...    4.0
# 22      after having a great time with a cheaper digit...    5.0
# 23      some folks talk about it's bulky size because ...    4.0
# 24      this camera is perfect and not complicated to ...    5.0
# 25      i'm not a professional photographer nor do i p...    5.0
# 26      i've taken over 1500 pictures in less than 3 m...    5.0
# 27      my first impression of elph s100 was that ther...    5.0
# 28      it was the only camera i brought on a tour thr...    4.0
# 29      the elph is not geared for those outdoor night...    5.0
# ...                                                   ...    ...
# 165724  as opposed to the previous models optical rang...    5.0
# 165725  its made of metal (anodized aluminium) is slee...    5.0
# 165726  the image stabilization is so good i find i ca...    5.0
# 165727  the smooth motorized optical on the 24-70mm le...    5.0
# 165728  i often shoot in focus mode, and using the lar...    5.0
# 165729  thanks to the large 1" image sensor and f1.8 l...    5.0
# 165730  i hardly used the flash as there is little nee...    5.0
# 165731  the regular lcd lcd can be tilted 180 degrees ...    5.0
# 165732                 apropos touch: the lcd lcd is not.    5.0
# 165733  one has to consult the paper focus to understa...    5.0
# 165734  (i have not read the focus yet ;)- battery lif...    5.0
# 165735  i short over 200 pictures on a day and still h...    5.0
# 165736  it also has problems with focus and brightenin...    5.0
# 165737  i still found shots that would be ruined becau...    5.0
# 165738  either disable this or make it an option in se...    4.0
# 165739  i hesitated at the rx100 and rx100 mkii becaus...    5.0
# 165740  i was unable to attach a microphone or flash u...    4.0
# 165741                     sflash tendency to overexpose.    5.0
# 165742    comparable performance to aps-c up to focus800.    5.0
# 165743  focus performance about this same as its prede...    5.0
# 165744  well, the lens isn't as sharp but still pretty...    5.0
# 165745         low flash performance is exactly the same.    5.0
# 165746  it has a sharp and fast zeiss lens 24-70 f1.8-...    5.0
# 165747  care must be taken with the flash, evf and lcd...    5.0
# 165748  the pictures are sharp, vivid and relatively f...    5.0
# 165749  one can pixel peep any lens into a corner (no ...    5.0
# 165750  "optical - as mentioned above the optical rang...    5.0
# 165751                   the optical speed is quite good.    5.0
# 165752  i can see using it a great deal with this came...    5.0
# 165753  despite 30+ years of photography i am still am...    5.0
#
#                                                user CS_SS         target  \
# 0                                               Lee    CS         c-2020
# 1                                           A. Gray    CS            vga
# 2                                     David Pirmann    CS            110
# 3                                Baltic Books "Vic"    CS          d-460
# 4                                                JR    CS           d450
# 5                                              wcc2    CS           d450
# 6                                  William C. Peden    CS           cmos
# 7              Dalibor Moyzes "artist-photographer"    CS       30d,eosm
# 8                                              Dave    CS  c-2000,c-3040
# 9                                        "wavshrdr"    CS          3000z
# 10                                        C. Comley    CS            d1x
# 11                                       "jagirard"    CS    dsc-s70,s20
# 12                                   Jay Pennington    CS            s20
# 13                                           J. Liu    CS       s100,s10
# 14                                      "kimbo5203"    CS           elph
# 15                                  Amazon Customer    CS           elph
# 16                                 Donald H. Lykins    CS            rca
# 17                                  Erwin Grellmann    CS           elph
# 18                     Me In Scottsdale AZ "JustMe"    CS           s100
# 19                             AmandaMacky "Amanda"    CS            d70
# 20             Dalibor Moyzes "artist-photographer"    CS       30d,eosm
# 21                                        "deepfry"    CS         c-2040
# 22                                       L. Wallach    CS        dsc-s30
# 23                                    Robin Coleman    CS          k1000
# 24                                         A. Schek    CS           elph
# 25                                               BB    CS       s100,s10
# 26                                     Brian Roache    CS           elph
# 27                              Cliff Bauer "Cliff"    CS           elph
# 28                                    D. Blickstein    CS           elph
# 29                      Diane E. Winkler "wink2001"    CS           elph
# ...                                             ...   ...            ...
# 165724                                      Richard    SS            NaN
# 165725                                      Richard    SS            NaN
# 165726                                   Rick Darke    SS            NaN
# 165727                                   Rick Darke    SS            NaN
# 165728                                   Rick Darke    SS            NaN
# 165729                             Robbert Patrison    SS            NaN
# 165730                             Robbert Patrison    SS            NaN
# 165731                             Robbert Patrison    SS            NaN
# 165732                             Robbert Patrison    SS            NaN
# 165733                             Robbert Patrison    SS            NaN
# 165734                             Robbert Patrison    SS            NaN
# 165735                             Robbert Patrison    SS            NaN
# 165736                                Ryan Matthews    SS            NaN
# 165737                                Ryan Matthews    SS            NaN
# 165738                                        Sam M    SS            NaN
# 165739                                        Scott    SS            NaN
# 165740                                   ScottyBear    SS            NaN
# 165741                                      S. Vogt    SS            NaN
# 165742                                      S. Vogt    SS            NaN
# 165743                                      S. Vogt    SS            NaN
# 165744                                      S. Vogt    SS            NaN
# 165745                                      S. Vogt    SS            NaN
# 165746  The Creative Fellow "Photographer/Mac Geek"    SS            NaN
# 165747                                   Walt Kurtz    SS            NaN
# 165748                                   Walt Kurtz    SS            NaN
# 165749                                   Walt Kurtz    SS            NaN
# 165750                                   Walt Kurtz    SS            NaN
# 165751                                   Walt Kurtz    SS            NaN
# 165752                                   Walt Kurtz    SS            NaN
# 165753                                   Walt Kurtz    SS            NaN
#
#                                       feature  polarity
# 0                                        lens         0
# 1                                     battery         0
# 2                                      memory         1
# 3       optical,battery,lcd,compression,flash         1
# 4                                     optical        -1
# 5                               battery,flash         1
# 6                                       pixel         0
# 7                                  lens,burst         1
# 8                                        lens         0
# 9                          memory,burst,flash         1
# 10                                    battery        -1
# 11                              pixel,battery         1
# 12                                      pixel         1
# 13                                      flash         1
# 14                                      pixel         0
# 15                                      flash         0
# 16                                      flash         1
# 17                                    optical         1
# 18                              optical,focus         0
# 19                                      focus         1
# 20                                 lens,burst         1
# 21                                       lens         1
# 22                                      pixel         1
# 23                                      flash        -1
# 24                       pixel,memory,battery         1
# 25                                    battery         0
# 26                       optical,memory,flash        -1
# 27                             memory,battery         0
# 28                                      focus         0
# 29                                      flash         0
# ...                                       ...       ...
# 165724                                optical         0
# 165725                            lens,memory         1
# 165726                            burst,focus         1
# 165727                           lens,optical         1
# 165728                             lens,focus         1
# 165729                       lens,focus,flash         0
# 165730                                  flash         1
# 165731                                    lcd         1
# 165732                                    lcd         0
# 165733                     lens,optical,focus         1
# 165734                          battery,focus         1
# 165735                          battery,focus        -1
# 165736                            focus,flash         0
# 165737                                  flash        -1
# 165738                                    lcd        -1
# 165739                                   lens         0
# 165740                                  flash        -1
# 165741                                  flash         0
# 165742                                  focus         0
# 165743                                  focus         0
# 165744                                   lens         1
# 165745                                  flash         0
# 165746                             lens,focus         1
# 165747                              lcd,flash        -1
# 165748                                  focus         1
# 165749                             pixel,lens         1
# 165750                                optical         1
# 165751                                optical         1
# 165752                                  burst        -1
# 165753                                  flash         1
#
# [165754 rows x 10 columns]

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
combine = [train_data, test_data]

# %%
train_data.info()
print('-' * 40)
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 평균 survived rate = 38%
# # 전체 평균 나이 29살
# #

# %%
train_data[['Sex', 'Survived']].groupby(['Sex']).mean().sort_values(by ='Survived', ascending = False)
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
train_data[['Pclass', 'Survived']].groupby(['Pclass']).mean().sort_values(by='Survived', ascending = False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
train_data[['Parch', 'Survived']].groupby(['Parch']).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#        Survived
# Parch
# 3      0.600000
# 1      0.550847
# 2      0.500000
# 0      0.343658
# 5      0.200000
# 4      0.000000
# 6      0.000000

# %% [markdown]
# # Visualizing
# ## Observations.
#
# #### - Infants (Age <=4) had high survival rate.
# #### - Oldest passengers (Age = 80) survived.
# #### - Large number of 15-25 year olds did not survive.
# #### - Most passengers are in 15-35 age range.
#
# ## Decisions.
#
# This simple analysis confirms our assumptions as decisions for subsequent workflow stages.
#
# #### - We should consider Age (our assumption classifying #2) in our model training.
# #### - Complete the Age feature for null values (completing #1).
# #### - We should band age groups (creating #3).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = sns.FacetGrid(train_data, col ='Survived')
g.map(plt.hist, 'Age', bins= 20)

# %% [markdown]
# # Correlating numerical and ordinal features
# We can combine multiple features for identifying correlations using a single plot. This can be done with numerical and categorical features which have numeric values.
#
# ## Observations.
#
# #### - Pclass=3 had most passengers, however most did not survive. Confirms our classifying assumption #2.
# #### - Infant passengers in Pclass=2 and Pclass=3 mostly survived. Further qualifies our classifying assumption #2.
# #### - Most passengers in Pclass=1 survived. Confirms our classifying assumption #3.
# #### - Pclass varies in terms of Age distribution of passengers.
#
# ## Decisions
#
# #### - Consider Pclass for model training.

# %%
grid = sns.FacetGrid(train_data, col = 'Survived', row = 'Pclass', size = 2.2, aspect= 1.6)
grid.map(plt.hist, 'Age', alpha = 0.5, bins = 20)
grid.add_legend()
# Out:
# C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
