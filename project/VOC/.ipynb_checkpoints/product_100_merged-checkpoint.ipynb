# %%
def source_target_identity(df):
    1. df['CS_SS']에서 CS만 뽑아둔다
    2. df['review'] 문장에 요한님한테 받은 프로덕트 리스트의 제품이 등장하면 df['target']에 추가
    3. target이 있는 row가 진짜 CS가 됨.
    4. 나머지는 drop처리

# %%
import pandas as pd

df = pd.read_csv('feature_labeling.csv')
df
# Out:
#               asin         date  \
# 0       B00000J48G  04 26, 2000
# 1       B00000J48G  05 18, 2001
# 2       B00000J48G  05 23, 2000
# 3       B00000J48G  03 13, 2000
# 4       B00000J48G   06 8, 2002
# 5       B00000J48G   06 8, 2002
# 6       B00000J48G   06 8, 2002
# 7       B00000J48G   06 8, 2002
# 8       B00000J48G   03 2, 2000
# 9       B00000JBIA  01 23, 2001
# 10      B00000JBIA   07 3, 2001
# 11      B00000JBIA  11 23, 2000
# 12      B00000JBIA  02 21, 2000
# 13      B00000JBIA   06 8, 2000
# 14      B00000JBIA   06 8, 2000
# 15      B00000JBIA  01 27, 2000
# 16      B00000JBIA  12 30, 2000
# 17      B00000JBIA   06 6, 2000
# 18      B00000JBIA  05 25, 2000
# 19      B00000JBIA  05 25, 2000
# 20      B00000JDEL   07 4, 2000
# 21      B00000JDEL   07 4, 2000
# 22      B00000JDEL  01 24, 2005
# 23      B00000JDEL  07 27, 2000
# 24      B00000JDEL  11 16, 2000
# 25      B00000JDEL  11 16, 2000
# 26      B00000JDEL  11 16, 2000
# 27      B00000JDEL  11 16, 2000
# ...

# %%
def lambdaa(x):
    if 'Canon EOS 7D' in x: return 'Canon EOS 7D'
    if 'Canon EOS 6D' in x: return 'Canon EOS 6D'
    if 'Canon PowerShot SX230 HS' in x: return 'Canon PowerShot SX230 HS'
    if 'Panasonic Lumix DMC-LX5' in x: return 'Panasonic Lumix DMC-LX5'
    if 'Sony DSC-RX100/B' in x: return 'Sony DSC-RX100/B'
    if 'Nikon D90' in x: return 'Nikon D90'
    if 'Canon Powershot S2 IS' in x: return 'Canon Powershot S2 IS'
    if 'Canon Powershot SX10IS' in x: return 'Canon Powershot SX10IS'
    if 'Sony NEX-5N' in x: return 'Sony NEX-5N'
    if 'Nikon D7100' in x: return 'Nikon D7100'
    if 'Nikon D700' in x : return 'Nikon D700'
    if 'Kodak EasyShare Z990' in x: return 'Kodak EasyShare Z990'
    if 'Canon PowerShot SD1400 IS' in x: return 'Canon PowerShot SD1400 IS'
    if 'Sony NEX-7' in x: return 'Sony NEX-7'
    if 'Canon EOS 50D' in x: return 'Canon EOS 50D'
    if 'Fujifilm FinePix HS10' in x: return 'Fujifilm FinePix HS10'
    if 'Sony Cyber-shot DSC-HX5V' in x: return 'Sony Cyber-shot DSC-HX5V'
    if 'Canon PowerShot SX160 IS' in x: return 'Canon PowerShot SX160 IS'
    if 'Fujifilm FinePix HS20' in x: return 'Fujifilm FinePix HS20'
    if 'Canon PowerShot SD850 IS' in x: return 'Canon PowerShot SD850 IS'
    if 'Sony Cyber-shot DSC-HX200V' in x: return 'Sony Cyber-shot DSC-HX200V'
    if 'Kodak Easyshare Z981' in x: return 'Kodak Easyshare Z981'
    if 'Canon EOS 70D' in x: return 'Canon EOS 70D'
    
    if 'Fujifilm FinePix Real 3D W3' in x: return 'Fujifilm FinePix Real 3D W3'
    if 'Nikon D5000' in x: return 'Nikon D5000'
    if 'Fujifilm X100' in x: return 'Fujifilm X100'
    if 'Panasonic LUMIX DMC-FZ70' in x: return 'Panasonic LUMIX DMC-FZ70'
    if 'Canon EOS M' in x: return 'Canon EOS M'
    if 'Canon PowerShot G15' in x: return 'Canon PowerShot G15'
    if 'Canon SX30IS 14' in x: return 'Canon SX30IS 14'
    if 'Canon PowerShot SD870IS' in x: return 'Canon PowerShot SD870IS'
    if 'Panasonic Lumix DMC-TZ3K' in x: return 'Panasonic Lumix DMC-TZ3K'
    if 'Sony NEX-6/B' in x: return 'Sony NEX-6/B'
    if 'Sony Cyber-shot DSC-HX9V' in x: return 'Sony Cyber-shot DSC-HX9V'
    if 'Olympus PEN E-PL1' in x: return 'Olympus PEN E-PL1'
    if 'Fujifilm X10' in x: return 'Fujifilm X10'
    if 'Canon PowerShot SX20IS' in x: return 'Canon PowerShot SX20IS'
    if 'Olympus OM-D E-M5' in x: return 'Olympus OM-D E-M5'
    if 'Panasonic LUMIX DMC-LX7W' in x: return 'Panasonic LUMIX DMC-LX7W'
    if 'Canon SX40 HS' in x: return 'Canon SX40 HS'
    if 'Canon EOS 40D' in x: return 'Canon EOS 40D'
    if 'Panasonic Lumix DMC-FZ35' in x: return 'Panasonic Lumix DMC-FZ35'
    if 'Canon EOS Rebel T1i' in x: return 'Canon EOS Rebel T1i'
    if 'Canon PowerShot SX130IS' in x: return 'Canon PowerShot SX130IS'
    if 'Canon PowerShot Pro Series S5' in x: return 'Canon PowerShot Pro Series S5'
    if 'Nikon D600' in x: return 'Nikon D600'
    if 'Canon PowerShot S90' in x: return 'Canon PowerShot S90'
    if 'Canon PowerShot SX150' in x: return 'Canon PowerShot SX150'
    return x

# %%
df['product'] = df['product'].apply(lambdaa)

# %%
df['product'].value_counts()[0:30]
# Out:
# Nikon D700                          3648
# Canon EOS 5D Mark II                2910
# Panasonic Lumix DMC-ZS3             2806
# Canon EOS Rebel T3i                 2327
# Canon PowerShot SX260               2321
# Canon PowerShot SX50 HS             2231
# Canon PowerShot S100                2137
# Canon PowerShot ELPH 300            2083
# Canon EOS 7D                        2080
# Canon Digital Rebel XSI             2030
# Panasonic Lumix DMC-ZS7             2013
# Canon EOS 60D                       1901
# Fujifilm X100                       1883
# Nikon D5100                         1879
# Nikon D800                          1874
# Canon PowerShot A590IS              1809
# Canon EOS 6D                        1769
# Canon PowerShot S95                 1722
# Canon PowerShot SX280               1668
# Nikon D3100                         1668
# Canon PowerShot SX230 HS            1652
# Panasonic Lumix DMC-FZ200           1613
# Panasonic Lumix ZS20                1597
# ...

# %%
df.to_csv('product_100.csv')

# %% [markdown]
# # 100개 리뷰가 가장 많은 제품들 추출

# %%
import pandas as pd
df = pd.read_csv('product_100(valuecount_top_100_merged).csv')

def extract_top_100_product_list(df):
    data = df['product'].value_counts()[:100]
    
    # 리뷰가 가장 많은 제품 100개 데이터프레임으로 만듬
    data = pd.DataFrame(data)
    data = data.reset_index()
    
    # 100개의 제품을 리스트형식으로 변경
    product_list_100 = list(data['index'])
    # 리스트내 단어들을 (word)|로 변경
    product_list_100 = '('+')|('.join(product_list_100)+')'
    # 통일성을 위해 모두 소문자로 변환
    product_list_100.lower()
    return product_list_100

top_100_list = extract_top_100_product_list(df)
print(top_100_list)

def extract_top_100_CS(df):
    product_list_100 = extract_top_100_product_list(df)
    
    #모든 제품 리스트에서 top100 제품이 있는 것만 출력
    df_100 = df[df['product'].str.contains(product_list_100) == True]
    
    # 출력된 top100제품들의 review에서 product_list_100에 호명된 제품만 출력
    x = df_100[df_100['review'].str.contains('(nikon d700)|(canon eos 5d mark ii)|(panasonic lumix dmc-zs3)|(canon eos rebel t3i)|(canon powershot sx260)|(canon powershot sx50 hs)|(canon powershot s100)|(canon powershot elph 300)|(canon eos 7d)|(canon digital rebel xsi)|(panasonic lumix dmc-zs7)|(canon eos 60d)|(fujifilm x100)|(nikon d5100)|(nikon d800)|(canon powershot a590is)|(canon eos 6d)|(canon powershot s95)|(canon powershot sx280)|(nikon d3100)|(canon powershot sx230 hs)|(panasonic lumix dmc-fz200)|(panasonic lumix zs20)|(panasonic lumix dmc-lx5)|(canon powershot pro series s3 is)|(sony dsc-rx100/b)|(nikon d90)|(canon powershot s2 is)|(panasonic lumix dmc-tz5s)|(canon powershot sx10is)|(anon rebel xt)|(canon powershot sd780is)|(canon powershot sx20is)|(canon powershot sd1000)|(olympus om-d e-m5)|(panasonic lumix dmc-lx7w)|(canon eos rebel t4i)|(canon sx40 hs)|(sony nex-5n)|(canon eos 40d)|(canon powershot sd800 is)|(canon rebel xti)|(panasonic lumix dmc-fz35)|(nikon coolpix p510)|(canon eos rebel t1i)|(canon powershot sx130is)|(canon powershot pro series s5)|(nikon d600)|(canon powershot s90)|(canon powershot sx150)|(sony nex-6/b)|(panasonic lumix dmc-tz3k)|(canon powershot sd1200is)|(canon powershot sx210is)|(canon eos m)|(canon powershot a570is)|(nikon d5000)|(canon powershot d10)|(canon powershot sd870is)|(canon eos rebel t3)|(canon sx30is 14)|(canon powershot sx110is)|(olympus pen e-pl1)|(panasonic  lumix dmc-fz28k)|(nikon coolpix s8100)|(nikon coolpix l820)|(sony cyber-shot dsc-hx9v)|(nikon coolpix s9100)|(fujifilm x10)|(canon powershot elph 110 hs)|(panasonic dmc-fz150k)|(nikon d7100)|(canon g12)|(sony cyber-shot dsc-wx150)|(kodak easyshare z990)|(canon powershot sd750)|(canon powershot sd1400 is)|(sony nex-7)|(ge power pro x500-bk)|(canon eos 50d)|(fujifilm finepix hs10)|(sony cyber-shot dsc-hx5v)|(canon powershot sx160 is)|(canon powershot a2300)|(canon eos 70d)|(canon powershot a1400)|(fujifilm finepix hs20)|(canon powershot sd850 is)|(sony cyber-shot dsc-hx200v)|(kodak easyshare z981)|(fujifilm finepix hs50exr)|(fujifilm finepix real 3d w3)|(panasonic lumix dmc-fz70)|(canon powershot g9)|(canon powershot elph 330)|(canon powershot g15)|(panasonic dmc-fh25k)|(nikon coolpix l22)|(canon powershot s400)|(fujifilm finepix s1800)') == True]
    
    # CS만 출력
    return x[x['CS_SS'] == 'CS']

top_100_CS = extract_top_100_CS(df)
print(top_100_CS)
# Out:
# (Nikon D700)|(Canon EOS 5D Mark II)|(Panasonic Lumix DMC-ZS3)|(Canon EOS Rebel T3i)|(Canon PowerShot SX260)|(Canon PowerShot SX50 HS)|(Canon PowerShot S100)|(Canon PowerShot ELPH 300)|(Canon EOS 7D)|(Canon Digital Rebel XSI)|(Panasonic Lumix DMC-ZS7)|(Canon EOS 60D)|(Fujifilm X100)|(Nikon D5100)|(Nikon D800)|(Canon PowerShot A590IS)|(Canon EOS 6D)|(Canon PowerShot S95)|(Canon PowerShot SX280)|(Nikon D3100)|(Canon PowerShot SX230 HS)|(Panasonic Lumix DMC-FZ200)|(Panasonic Lumix ZS20)|(Panasonic Lumix DMC-LX5)|(Canon PowerShot Pro Series S3 IS)|(Sony DSC-RX100/B)|(Nikon D90)|(Canon Powershot S2 IS)|(Panasonic Lumix DMC-TZ5S)|(Canon Powershot SX10IS)|(anon Rebel XT)|(Canon PowerShot SD780IS)|(Canon PowerShot SX20IS)|(Canon PowerShot SD1000)|(Olympus OM-D E-M5)|(Panasonic LUMIX DMC-LX7W)|(Canon EOS Rebel T4i)|(Canon SX40 HS)|(Sony NEX-5N)|(Canon EOS 40D)|(Canon PowerShot SD800 IS)|(Canon Rebel XTi)|(Panasonic Lumix DMC-FZ35)|(Nikon COOLPIX P510)|(Canon EOS Rebel T1i)|(Canon PowerShot SX1
# ...

# %%
df
# Out:
#         Unnamed: 0        asin         date  \
# 0                0  B00000J48G  04 26, 2000
# 1                1  B00000J48G  05 18, 2001
# 2                2  B00000J48G  05 23, 2000
# 3                3  B00000J48G  03 13, 2000
# 4                4  B00000J48G   06 8, 2002
# 5                5  B00000J48G   06 8, 2002
# 6                6  B00000J48G   06 8, 2002
# 7                7  B00000J48G   06 8, 2002
# 8                8  B00000J48G   03 2, 2000
# 9                9  B00000JBIA  01 23, 2001
# 10              10  B00000JBIA   07 3, 2001
# 11              11  B00000JBIA  11 23, 2000
# 12              12  B00000JBIA  02 21, 2000
# 13              13  B00000JBIA   06 8, 2000
# 14              14  B00000JBIA   06 8, 2000
# 15              15  B00000JBIA  01 27, 2000
# 16              16  B00000JBIA  12 30, 2000
# 17              17  B00000JBIA   06 6, 2000
# 18              18  B00000JBIA  05 25, 2000
# 19              19  B00000JBIA  05 25, 2000
# ...
