# %%
import pandas as pd
from nltk import sent_tokenize
# encoding 문제시, engine = 'python' 입력할 것
data = pd.read_csv('amazon_test.csv', engine = 'python')
data.head()
# Out:
#                                         product_name  \
# 0  Waterproof Digital Camera FHD 1080P Underwater...
# 1  Waterproof Digital Camera FHD 1080P Underwater...
# 2  Waterproof Digital Camera FHD 1080P Underwater...
# 3  Waterproof Digital Camera FHD 1080P Underwater...
# 4  Waterproof Digital Camera FHD 1080P Underwater...
#
#                                               review    review_date  \
# 0  The packaging is nice and the camera looks goo...  July 18, 2019
# 1  Super feel, fine workmanship, many functions. ...   July 8, 2019
# 2  The shooting effect is good, the quality is ve...  July 11, 2019
# 3  If you want a camera that is simple to use and...  July 19, 2019
# 4  Will not charge using the brick it came with. ...  July 12, 2019
#
#                 score                  user
# 0  2.0 out of 5 stars             Charlotte
# 1  5.0 out of 5 stars        Harris Minerva
# 2  5.0 out of 5 stars          Jeff Stegall
# 3  1.0 out of 5 stars  Christopher D. Reddy
# 4  2.0 out of 5 stars       Amazon Customer

# %%
import pandas as pd
from nltk import sent_tokenize
import re

def make_same_feature(text):
    
    text=re.sub('resolution|pixel|megapixel', 'pixel', text)
    text=re.sub('lens|wide\sangle|normal\srange', 'lens', text)
    text=re.sub('optical|zoom|optical\szoom|digital\szoom', 'optical', text)
    text=re.sub('memory|megabytes|MB', 'memory', text)
    text=re.sub('burst|continuous|shutter|recovery|motion|sport', 'burst', text)
    text=re.sub('battery|batteries|power', 'battery', text)
    text=re.sub('focus|exposure|manual|iso', 'focus', text)
    text=re.sub('LCD|screen', 'LCD', text)
    text=re.sub('compression|compress|jpeg', 'compression', text)
    text=re.sub('flash|light', 'flash', text)
    return text

def pre_processing(data):
    data['score'] = data['score'].apply(lambda x : x.split(' ')[0])
    
    result = []
    for i in range(len(data)):
        product = data.loc[i, 'product_name']
        date = data.loc[i, 'review_date']
        score = data.loc[i, 'score']
        user = data.loc[i, 'user']
        text = data.loc[i, 'review']

        Sentences_list = sent_tokenize(text)
        for txt in Sentences_list:
            dict_n = {
                'product' : product,
                'date' : date,
                'score' : score,
                'user' : user,
                'review' : txt
            }
            result.append(dict_n)

    df = pd.DataFrame(result)
    df['review'] = df['review'].apply(make_same_feature)
    df[df.review.str.contains('pixel|lens|optical|memory|burst|battery|focus|LCD|compression|flash')== True]

    return df

# %%
data_pp=pre_processing(data)
data_pp
# Out:
#                date                                            product  \
# 0     July 18, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 1     July 18, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 2     July 18, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 3      July 8, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 4      July 8, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 5      July 8, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 6     July 11, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 7     July 11, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 8     July 19, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 9     July 19, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 10    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 11    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 12    July 26, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 13    July 27, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 14    July 10, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 15    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 16    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 17    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 18    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 19    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 20    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 21    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 22    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 23    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 24    July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 25     July 8, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 26     July 8, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 27     July 8, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 28     July 8, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 29    June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# ...             ...                                                ...
# 6530  July 20, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6531  July 20, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6532  July 20, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6533  July 12, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6534  July 13, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6535  July 13, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6536  July 13, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6537   July 6, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6538  July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6539  July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6540  July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6541  July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6542  July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6543  July 25, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6544  July 25, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6545  July 21, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6546  July 21, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6547  July 16, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6548  July 16, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6549  July 16, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6550  July 16, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6551  July 30, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6552  July 21, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6553  July 21, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6554  July 21, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6555  July 21, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6556  July 18, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6557  July 18, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6558  July 18, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6559  July 24, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
#
#                                                  review score  \
# 0     The packaging is nice and the camera looks goo...   2.0
# 1     We ordered this for my daughter to take to cam...   2.0
# 2     If a camera is going to lack a critical compon...   2.0
# 3         Super feel, fine workmanship, many functions.   5.0
# 4     Strong video shooting ability, high-definition...   5.0
# 5     The main waterproof effect is very good, five-...   5.0
# 6     The shooting effect is good, the quality is ve...   5.0
# 7     A lot of random accessories, a wide range of a...   5.0
# 8     If you want a camera that is simple to use and...   1.0
# 9                                               Period.   1.0
# 10        Will not charge using the brick it came with.   2.0
# 11    Have to take my laptop with me when I travel j...   2.0
# 12    a black camera wow.my classroom usually had te...   5.0
# 13    Poor quality for the cost the pictures are nuc...   1.0
# 14    Terrible picture quality and it is NOT waterpr...   1.0
# 15            Used it for a week of snorkeling at USVI.   5.0
# 16                        So no depth waterproof tests.   5.0
# 17    I did play with it ahead of time and buttons e...   5.0
# 18    Buttons are easy to use underwater without glo...   5.0
# 19    I mostly like its video quality and the capabi...   5.0
# 20    The camera came with waterproof cover so, did ...   5.0
# 21    Works well in low flash conditions as well, th...   5.0
# 22    This is the first action camera I have owned a...   5.0
# 23    Given the price of the product, its a neat deal!!   5.0
# 24    !,I would recommend this product if someone is...   5.0
# 25                      Baby, it's exactly what I need.   5.0
# 26         When I receive it, it's packaged completely.   5.0
# 27    What surprises me when I open it is that baby ...   5.0
# 28    The picture quality is clear, the color is bea...   5.0
# 29    I was really skeptical of getting this camera ...   5.0
# ...                                                 ...   ...
# 6530                                My girls love this!   5.0
# 6531  It has a lot of the features of an actual came...   5.0
# 6532  It fell a couple times from my daughters hands...   5.0
# 6533  My son thinks of himself as a photographer, ta...   5.0
# 6534                   this is such an amazing product.   5.0
# 6535  The image quality is good too, tho I didn��셳 p...   5.0
# 6536      I really really like it, and my son does too.   5.0
# 6537  My daughter is so happy with it, the picture q...   5.0
# 6538                            Bought for my daughter.   5.0
# 6539                                   Very good price.   5.0
# 6540                     Simple for hr to work and use.   5.0
# 6541                              Takes great pictures.   5.0
# 6542                                      She loves it!   5.0
# 6543  I bought this as a gift for my little cousin a...   5.0
# 6544  The design is very cute and the quality of the...   5.0
# 6545  This child camera is very popular for my child...   5.0
# 6546  It is a good development of the child's brain ...   5.0
# 6547                      For my daughter she loves it.   5.0
# 6548                                 Nice gift to kids.   5.0
# 6549                      It looks great and beautiful.   5.0
# 6550                                 My niece loves it.   5.0
# 6551  Bought it for little girl��셲 birthday, she lov...   5.0
# 6552        Hahaha..this��셲 a little small cute camera.   5.0
# 6553     Before I buy I was so worry about the quality.   5.0
# 6554                                  Now I believe it.   5.0
# 6555                        I love it so much �윑곾윑곾윑곾윑�   5.0
# 6556  This camera is cute, easy to use and has good ...   5.0
# 6557  It can be set with different scenes and decora...   5.0
# 6558                      My child is happy to have it.   5.0
# 6559  Very good camera, the child can't put it down,...   5.0
#
#                       user
# 0                Charlotte
# 1                Charlotte
# 2                Charlotte
# 3           Harris Minerva
# 4           Harris Minerva
# 5           Harris Minerva
# 6             Jeff Stegall
# 7             Jeff Stegall
# 8     Christopher D. Reddy
# 9     Christopher D. Reddy
# 10         Amazon Customer
# 11         Amazon Customer
# 12                   wondy
# 13         Kindle Customer
# 14         Amazon Customer
# 15                 beverly
# 16                 beverly
# 17                 beverly
# 18                 beverly
# 19                 beverly
# 20                 beverly
# 21                 beverly
# 22                 beverly
# 23                 beverly
# 24                 beverly
# 25               Bryan Joe
# 26               Bryan Joe
# 27               Bryan Joe
# 28               Bryan Joe
# 29                   CIMC7
# ...                    ...
# 6530                Owj377
# 6531                Owj377
# 6532                Owj377
# 6533               Charlie
# 6534                Snowie
# 6535                Snowie
# 6536                Snowie
# 6537                   Ons
# 6538               brianna
# 6539               brianna
# 6540               brianna
# 6541               brianna
# 6542               brianna
# 6543                  Aroa
# 6544                  Aroa
# 6545                winter
# 6546                winter
# 6547             Michael Y
# 6548             Michael Y
# 6549        Pei Hsuan Chen
# 6550        Pei Hsuan Chen
# 6551                 cathy
# 6552       Amazon Customer
# 6553       Amazon Customer
# 6554       Amazon Customer
# 6555       Amazon Customer
# 6556                Sophia
# 6557                Sophia
# 6558                Sophia
# 6559          Zhengjuan Xi
#
# [6560 rows x 5 columns]

# %%
aa = data_pp[data_pp.review.str.contains('pixel|lens|optical|memory|burst|battery|focus|LCD|compression|flash')== True]
aa
# Out:
#                    date                                            product  \
# 21        July 12, 2019  Waterproof Digital Camera FHD 1080P Underwater...
# 30        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 33        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 39        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 42        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 48        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 51        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 52        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 54        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 60        June 11, 2017  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 64        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 65        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 66        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 70        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 72        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 73        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 74        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 75        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 77        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 79        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 80        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 84        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 86        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 87        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 93        June 29, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 97     November 1, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 100    November 1, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 101    November 1, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 102    November 1, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# 103    November 1, 2018  PANASONIC LUMIX FZ80 4K Digital Camera, 18.1 M...
# ...                 ...                                                ...
# 6244      June 30, 2018  Kodak PIXPRO Friendly Zoom FZ53-BK 16MP Digita...
# 6245      June 30, 2018  Kodak PIXPRO Friendly Zoom FZ53-BK 16MP Digita...
# 6246      April 7, 2017  Kodak PIXPRO Friendly Zoom FZ53-BK 16MP Digita...
# 6262     March 18, 2019  Kodak PIXPRO Friendly Zoom FZ53-BK 16MP Digita...
# 6269  February 14, 2019  Kodak PIXPRO Friendly Zoom FZ53-BK 16MP Digita...
# 6296      July 12, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6302      July 30, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6337      July 24, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6347       July 6, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6364      July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6367      July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6368      July 17, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6380      July 10, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6383       July 8, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6399      July 10, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6404       July 3, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6417       July 5, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6422       July 8, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6427       July 8, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6445      July 10, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6448      July 10, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6450      July 13, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6456      July 10, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6459      July 11, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6462      July 11, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6467      July 11, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6475      July 11, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6496      July 31, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6507      July 12, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
# 6523      July 22, 2019  [16GB Memory Card Include] RegeMoudal Kids Dig...
#
#                                                  review score  \
# 21    Works well in low flash conditions as well, th...   5.0
# 30    She had a cheap Nikon Coolpix point and shoot ...   5.0
# 33    She loved the optical on the Nikon Coolpix P90...   5.0
# 39                Oh, the burst release lag is minimal.   5.0
# 42    After locking the focus by half-pressing the b...   5.0
# 48                           And that was in low flash.   5.0
# 51    The optical is not super fast in terms of spee...   5.0
# 52    The lens is SUPER WIDE, and it is respectably ...   5.0
# 54    The camera has like 200 memory internal memory...   5.0
# 60    Enclosed are snapshots testing the colors...an...   5.0
# 64          Pros:,The optical is truly awesome in this.   4.0
# 65                             No SLR lens can compare.   4.0
# 66    It's great for birdwatching, opticaling in on ...   4.0
# 70    Horrible to do on the camera's LCD, I wound up...   4.0
# 72    I wanted something that would create 30 images...   4.0
# 73    As this feature is why I chose the Lumix over ...   4.0
# 74    To the point that you will have low flash issu...   4.0
# 75    The F2.8 for the lens in wide isn't matched by...   4.0
# 77    I've played with the flash levels and it is cl...   4.0
# 79    This is an AMAZING outdoor daytime camera, but...   4.0
# 80    Generally, optical and autofocus are fantastic...   4.0
# 84    (maybe custom, but defaults to 1080p/60fps), a...   4.0
# 86    Missed 1/2 of my kids' Karate class trying to ...   4.0
# 87    The autofocusing on a leaf can be annoying, bu...   4.0
# 93    Because of the crappy low flash, I still use m...   4.0
# 97    Rather than read the online focuss, I watched ...   5.0
# 100   The claims that the camera doesn't perform in ...   5.0
# 101   I took the camera to the hockey rink and shot ...   5.0
# 102   I played around operating the camera in differ...   5.0
# 103   Admittedly, the flashing was not in my favor f...   5.0
# ...                                                 ...   ...
# 6244  The camera is unable to charge any of several ...   1.0
# 6245  It seems that an inability to recharge battery...   1.0
# 6246  The camera took excellent pictures and was fla...   5.0
# 6262  Sometimes there is a streak of flash showing i...   4.0
# 6269  Camera is perfect for everyone to use and the ...   5.0
# 6296            It is small and flash enough for a kid!   5.0
# 6302  It is entertaining for a toddler, liked the fa...   5.0
# 6337     Love that you have different LCDs you can use.   5.0
# 6347                          It has memory card in it!   5.0
# 6364  But to tell the truth quality of the camera is...   5.0
# 6367  Camera comes very well packed, the kit include...   5.0
# 6368  It has impressive battery life, since we got i...   5.0
# 6380  There is a 16GB memory card in it, which can s...   5.0
# 6383  혻I do photography as a hobby and use some expe...   5.0
# 6399  The fact that the memory card came with it is ...   5.0
# 6404  It has a memory card so all photos can be tran...   5.0
# 6417               The camera is flash weight and soft.   5.0
# 6422  The camera feels very flashweight and it's qui...   5.0
# 6427  The camera is really easy to use and I love ho...   5.0
# 6445          The camera is a flash pink it is so cute.   5.0
# 6448  We do not have to put in battery it's recharge...   5.0
# 6450  The appearance is very flash, specially design...   5.0
# 6456  He loves it so much he��셲 always taking pictur...   5.0
# 6459              This camera is small and flashweight.   5.0
# 6462                           It has 16GB memory card.   5.0
# 6467  The best part is that it is rechargeable and i...   5.0
# 6475  It is a great size for little hands and is fla...   5.0
# 6496  The memory card has enough space for taking lo...   5.0
# 6507  Unexpectedly, the function of this children's ...   5.0
# 6523  By pressing the burst button, you will hear a ...   5.0
#
#                       user
# 21                 beverly
# 30                   CIMC7
# 33                   CIMC7
# 39                   CIMC7
# 42                   CIMC7
# 48                   CIMC7
# 51                   CIMC7
# 52                   CIMC7
# 54                   CIMC7
# 60                   CIMC7
# 64            John Roberts
# 65            John Roberts
# 66            John Roberts
# 70            John Roberts
# 72            John Roberts
# 73            John Roberts
# 74            John Roberts
# 75            John Roberts
# 77            John Roberts
# 79            John Roberts
# 80            John Roberts
# 84            John Roberts
# 86            John Roberts
# 87            John Roberts
# 93            John Roberts
# 97             JerryInLodi
# 100            JerryInLodi
# 101            JerryInLodi
# 102            JerryInLodi
# 103            JerryInLodi
# ...                    ...
# 6244               Flagman
# 6245               Flagman
# 6246                 Linda
# 6262       Jacob or Brenda
# 6269           Brian Miros
# 6296                 Doris
# 6302                    CG
# 6337                   Lee
# 6347                Daniel
# 6364     Veronika Kolikova
# 6367     Veronika Kolikova
# 6368     Veronika Kolikova
# 6380                  Macy
# 6383           Binary Raja
# 6399       Jordan and John
# 6404      Veronika Zhvania
# 6417            Eric James
# 6422               Sharon
# 6427               Sharon
# 6445            eli thomas
# 6448            eli thomas
# 6450                 happy
# 6456          DianaDelgado
# 6459       Patricia Revere
# 6462       Patricia Revere
# 6467           Marielglz07
# 6475  Making Mommy Reviews
# 6496            Ying Zhang
# 6507                 Huang
# 6523     Marsha Allbritten
#
# [1506 rows x 5 columns]

# %%
print(data_pp.loc[1,'review'])
print(data_pp.loc[2,'review'])
print(data_pp.loc[3,'review'])
# Out:
# We ordered this for my daughter to take to camp and only discovered the SD cars isn��셳 included after she opened it at camp.
# If a camera is going to lack a critical component that is usually included in cameras then it should be noted clearly and prominently - the only mention is deep in the poorly written description saying ��쐏lease kindly prepare one before discovering this camera���.
# Super feel, fine workmanship, many functions.
