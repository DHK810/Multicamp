# %%
import pandas as pd
from nltk import sent_tokenize
# encoding 문제시, engine = 'python' 입력할 것
data = pd.read_csv('output.csv', engine = 'python')
data.head()
# Out:
#    Unnamed: 0        asin item_model_no  \
# 0           0  B07S1HTSGH           NaN
# 1           1  B07S1HTSGH           NaN
# 2           2  B07S1HTSGH           NaN
# 3           3  B07S1HTSGH           NaN
# 4           4  B07S1HTSGH           NaN
#
#                                         product_name  \
# 0  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 1  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 2  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 3  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 4  Digital Camera with WiFi 24.0 MP Vlogging Came...
#
#                                               review    review_date  \
# 0  I have a professional Nikon camera purchased s...  June 30, 2019
# 1  I like this camera but it was not what i expec...   July 4, 2019
# 2  Now is a good time to travel.I'm a novice phot...  June 25, 2019
# 3  I'm not sure if it was just the camera that I ...  July 20, 2019
# 4  Looks good. Ok for taking our holiday snaps an...  July 15, 2019
#
#                 score               user
# 0  5.0 out of 5 stars           Arsenals
# 1  5.0 out of 5 stars  Samira Alshaibani
# 2  5.0 out of 5 stars    Vargas Laurence
# 3  3.0 out of 5 stars              Diane
# 4  5.0 out of 5 stars        shawn mayun

# %%
data = data.dropna(axis=0)

# %%
data
# Out:
#         Unnamed: 0        asin  \
# 58              58        asin
# 59              59  B01BVV6G72
# 60              60  B01BVV6G72
# 61              61  B01BVV6G72
# 62              62  B01BVV6G72
# 63              63  B01BVV6G72
# 64              64  B01BVV6G72
# 65              65  B01BVV6G72
# 66              66  B01BVV6G72
# 67              67  B01BVV6G72
# 68              68  B01BVV6G72
# 69              69  B07S1HTSGH
# 70              70  B07S1HTSGH
# 71              71  B07S1HTSGH
# 72              72  B07S1HTSGH
# 73              73  B07S1HTSGH
# 74              74  B07S1HTSGH
# 75              75  B07S1HTSGH
# 76              76  B07S1HTSGH
# 77              77  B07S1HTSGH
# 78              78  B07S1HTSGH
# 79              79  B019UDHT6U
# 80              80  B019UDHT6U
# 81              81  B019UDHT6U
# 82              82  B019UDHT6U
# 83              83  B019UDHT6U
# 84              84  B019UDHT6U
# 85              85  B019UDHT6U
# 86              86  B019UDHT6U
# 87              87  B019UDHT6U
# ...            ...         ...
# 103338        6201  B019UDI5PO
# 103339        6202  B019UDI5PO
# 103340        6203  B019UDI5PO
# 103341        6204  B019UDI5PO
# 103342        6205  B019UDI5PO
# 103343        6206  B019UDI5PO
# 103344        6207  B019UDI5PO
# 103345        6208  B019UDI5PO
# 103346        6209  B019UDI5PO
# 103347        6210  B019UDI5PO
# 103348        6211  B019UDHT6U
# 103349        6212  B019UDHT6U
# 103350        6213  B019UDHT6U
# 103351        6214  B019UDHT6U
# 103352        6215  B019UDHT6U
# 103353        6216  B019UDHT6U
# 103354        6217  B019UDHT6U
# 103355        6218  B019UDHT6U
# 103356        6219  B019UDHT6U
# 103357        6220  B019UDHT6U
# 103358        6221  B019UDHT6U
# 103359        6222  B019UDHT6U
# 103360        6223  B019UDHT6U
# 103361        6224  B019UDHT6U
# 103362        6225  B019UDHT6U
# 103363        6226  B019UDHT6U
# 103364        6227  B019UDHT6U
# 103365        6228  B019UDHT6U
# 103366        6229  B019UDHT6U
# 103367        6230  B019UDHT6U
#
#                                          item_model_no  \
# 58                                       item_model_no
# 59                  Canon-PowerShot-ELPH-180-Accessory
# 60                  Canon-PowerShot-ELPH-180-Accessory
# 61                  Canon-PowerShot-ELPH-180-Accessory
# 62                  Canon-PowerShot-ELPH-180-Accessory
# 63                  Canon-PowerShot-ELPH-180-Accessory
# 64                  Canon-PowerShot-ELPH-180-Accessory
# 65                  Canon-PowerShot-ELPH-180-Accessory
# 66                  Canon-PowerShot-ELPH-180-Accessory
# 67                  Canon-PowerShot-ELPH-180-Accessory
# 68                  Canon-PowerShot-ELPH-180-Accessory
# 69      Digital-Camera-Vlogging-Retractable-Flashlight
# 70      Digital-Camera-Vlogging-Retractable-Flashlight
# 71      Digital-Camera-Vlogging-Retractable-Flashlight
# 72      Digital-Camera-Vlogging-Retractable-Flashlight
# 73      Digital-Camera-Vlogging-Retractable-Flashlight
# 74      Digital-Camera-Vlogging-Retractable-Flashlight
# 75      Digital-Camera-Vlogging-Retractable-Flashlight
# 76      Digital-Camera-Vlogging-Retractable-Flashlight
# 77      Digital-Camera-Vlogging-Retractable-Flashlight
# 78      Digital-Camera-Vlogging-Retractable-Flashlight
# 79        Canon-PowerShot-Digital-Camera-Stabilization
# 80        Canon-PowerShot-Digital-Camera-Stabilization
# 81        Canon-PowerShot-Digital-Camera-Stabilization
# 82        Canon-PowerShot-Digital-Camera-Stabilization
# 83        Canon-PowerShot-Digital-Camera-Stabilization
# 84        Canon-PowerShot-Digital-Camera-Stabilization
# 85        Canon-PowerShot-Digital-Camera-Stabilization
# 86        Canon-PowerShot-Digital-Camera-Stabilization
# 87        Canon-PowerShot-Digital-Camera-Stabilization
# ...                                                ...
# 103338          Canon-PowerShot-Digital-Camera-Optical
# 103339          Canon-PowerShot-Digital-Camera-Optical
# 103340          Canon-PowerShot-Digital-Camera-Optical
# 103341          Canon-PowerShot-Digital-Camera-Optical
# 103342          Canon-PowerShot-Digital-Camera-Optical
# 103343          Canon-PowerShot-Digital-Camera-Optical
# 103344          Canon-PowerShot-Digital-Camera-Optical
# 103345          Canon-PowerShot-Digital-Camera-Optical
# 103346          Canon-PowerShot-Digital-Camera-Optical
# 103347          Canon-PowerShot-Digital-Camera-Optical
# 103348    Canon-PowerShot-Digital-Camera-Stabilization
# 103349    Canon-PowerShot-Digital-Camera-Stabilization
# 103350    Canon-PowerShot-Digital-Camera-Stabilization
# 103351    Canon-PowerShot-Digital-Camera-Stabilization
# 103352    Canon-PowerShot-Digital-Camera-Stabilization
# 103353    Canon-PowerShot-Digital-Camera-Stabilization
# 103354    Canon-PowerShot-Digital-Camera-Stabilization
# 103355    Canon-PowerShot-Digital-Camera-Stabilization
# 103356    Canon-PowerShot-Digital-Camera-Stabilization
# 103357    Canon-PowerShot-Digital-Camera-Stabilization
# 103358    Canon-PowerShot-Digital-Camera-Stabilization
# 103359    Canon-PowerShot-Digital-Camera-Stabilization
# 103360    Canon-PowerShot-Digital-Camera-Stabilization
# 103361    Canon-PowerShot-Digital-Camera-Stabilization
# 103362    Canon-PowerShot-Digital-Camera-Stabilization
# 103363    Canon-PowerShot-Digital-Camera-Stabilization
# 103364    Canon-PowerShot-Digital-Camera-Stabilization
# 103365    Canon-PowerShot-Digital-Camera-Stabilization
# 103366    Canon-PowerShot-Digital-Camera-Stabilization
# 103367    Canon-PowerShot-Digital-Camera-Stabilization
#
#                                              product_name  \
# 58                                           product_name
# 59      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 60      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 61      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 62      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 63      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 64      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 65      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 66      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 67      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 68      Canon PowerShot ELPH 180 20 MP Digital Camera ...
# 69      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 70      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 71      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 72      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 73      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 74      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 75      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 76      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 77      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 78      Digital Camera with WiFi 24.0 MP Vlogging Came...
# 79      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 80      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 81      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 82      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 83      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 84      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 85      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 86      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 87      Canon PowerShot ELPH 180 Digital Camera w/Imag...
# ...                                                   ...
# 103338  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103339  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103340  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103341  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103342  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103343  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103344  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103345  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103346  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103347  Canon PowerShot SX420 Digital Camera w/ 42x Op...
# 103348  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103349  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103350  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103351  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103352  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103353  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103354  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103355  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103356  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103357  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103358  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103359  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103360  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103361  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103362  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103363  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103364  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103365  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103366  Canon PowerShot ELPH 180 Digital Camera w/Imag...
# 103367  Canon PowerShot ELPH 180 Digital Camera w/Imag...
#
#                                                    review         review_date  \
# 58                                                 review         review_date
# 59      Takes a few seconds to focus but the pictures ...      March 29, 2018
# 60      It came with everything noted, but also with t...        June 2, 2018
# 61      I am a senior...travel a lot...am NOT smart ph...       July 21, 2018
# 62      I'm a 71 year old who has pondered for years w...     August 30, 2018
# 63      This is a great camera to have when you need s...      April 15, 2018
# 64      A very nice camera and collection of accessori...   September 7, 2017
# 65      Bought this for my wife for Xmas and she loves...    January 24, 2018
# 66      Easy to use, and a great bunch of super cool '...   December 11, 2017
# 67      After reading the other reviews we purchased t...    February 5, 2018
# 68      Well, for a P&S, this is a pretty good camera....   December 21, 2017
# 69      I have a professional Nikon camera purchased s...       June 30, 2019
# 70      I like this camera but it was not what i expec...        July 4, 2019
# 71      Now is a good time to travel.I'm a novice phot...       June 25, 2019
# 72      I'm not sure if it was just the camera that I ...       July 20, 2019
# 73      Looks good. Ok for taking our holiday snaps an...       July 15, 2019
# 74      Poor instructions,No clear way to turn off vid...       July 26, 2019
# 75      This camera is bought for a birthday gift for ...        July 5, 2019
# 76      I was actually surprised about this camera. Yo...      August 2, 2019
# 77      I very like it, user friendly, easy operation,...       July 10, 2019
# 78      It is small竊똠ompact camera with required funct...       July 25, 2019
# 79      혻I do professional photography for a living bu...       June 12, 2017
# 80      혻Okay. I gave it 5 stars because I love the ca...      August 6, 2017
# 81      This point and shoot has been great to use and...   February 24, 2016
# 82      I wanted a small, easy to use camera that coul...  September 28, 2017
# 83      We take a lot of vacations and many photos for...  September 17, 2018
# 84      At this price point, I wasn't expecting much. ...        July 9, 2017
# 85      This is a wonderful camera. If you��셶e ever ow...        May 20, 2017
# 86      It's the perfect pocket camera.  Very easy to ...       June 23, 2017
# 87      After opening my camera it worked great until ...   December 14, 2017
# ...                                                   ...                 ...
# 103338  This camera stinks! I wish I had sent it back ...       July 29, 2019
# 103339          Good basic camera. Lightweight and small!      March 29, 2018
# 103340  Works horrible. Not what I would expect for a ...     August 23, 2017
# 103341  The zoom is amazing but the photo quality is n...      March 28, 2017
# 103342  now learning how to not move when i click the ...     January 8, 2018
# 103343  The zoom is awesome, will need a tripod for ma...       July 30, 2018
# 103344                                 Good travel camera        May 18, 2018
# 103345  It��셲 a awesome camera need to transfer the ph...     January 3, 2019
# 103346  Made a great gift. Easy to use and takes quali...    January 22, 2019
# 103347  I am pleased with the camera. I just wish I wo...     January 9, 2019
# 103348  I use this for work and it is a great way to s...   September 5, 2017
# 103349  good product, parts made a little cheaply for ...     October 9, 2017
# 103350  The camera works great.  Have not figured out ...       July 20, 2017
# 103351     Wonderful little camera, great pic and videos!    October 27, 2017
# 103352                       Easy to use. Great pictures.    November 6, 2017
# 103353  Clear sharp pix - easy to use.  Ideal for basi...     August 22, 2017
# 103354   Takes good photos, easy to use and light weight.   September 1, 2017
# 103355                                         I love it!    November 6, 2017
# 103356  Works well for hobbiest.  Needed a camera for ...   September 4, 2017
# 103357                                            LOVE IT     October 1, 2017
# 103358                everything that I expected it to be     August 25, 2017
# 103359         My daughter loves it,,Great for a biggener     August 16, 2017
# 103360                                  excellent product  September 26, 2017
# 103361  Bought this for a month-long trip overseas. It...       July 20, 2017
# 103362                                      It is great !     August 31, 2017
# 103363                                   Love this camera     August 11, 2017
# 103364                       Small compact & easy to use.  September 11, 2017
# 103365  Not a great camera for me. I like a good camer...      March 31, 2017
# 103366              Excellant camera, just what I needed.      August 3, 2017
# 103367          Just what I was looking for -great photos      August 5, 2017
#
#         score               user
# 58      score               user
# 59        4.0    Kindle Customer
# 60        4.0   Kristin Maryland
# 61        4.0        tom colucci
# 62        5.0          Lee Coady
# 63        4.0     Michelle Smith
# 64        5.0            F. Clef
# 65        5.0             Dustin
# 66        5.0       Dr. Richards
# 67        5.0   Steven Schneider
# 68        5.0  Donnabeth Stewart
# 69        5.0           Arsenals
# 70        5.0  Samira Alshaibani
# 71        5.0    Vargas Laurence
# 72        3.0              Diane
# 73        5.0        shawn mayun
# 74        2.0      Her Babsiness
# 75        5.0        lilygallego
# 76        5.0            Brandon
# 77        5.0   Elizebeth Thomas
# 78        5.0               Ling
# 79        3.0       C. H. Greene
# 80        5.0       Brett Ashton
# 81        5.0       Kevin Breeze
# 82        5.0  Sacramento reader
# 83        1.0            William
# 84        5.0         Book Ninja
# 85        5.0           Nicholas
# 86        5.0     Donald Ferencz
# 87        1.0    Amazon Customer
# ...       ...                ...
# 103338    1.0            CCasson
# 103339    4.0       Fred Kagi Jr
# 103340    1.0      Lauren Greene
# 103341    4.0    Amazon Customer
# 103342    5.0           E. Gawel
# 103343    4.0    Amazon Customer
# 103344    5.0     mark sandblast
# 103345    5.0                joe
# 103346    5.0             Lauren
# 103347    4.0    Amazon Customer
# 103348    5.0    Amazon Customer
# 103349    4.0    Amazon Customer
# 103350    4.0          Mustang64
# 103351    5.0    Amazon Customer
# 103352    4.0      Julie Fureigh
# 103353    5.0                 DL
# 103354    5.0           H Sasaki
# 103355    5.0    Jeannette Lewis
# 103356    5.0   Mary  Ann Elmore
# 103357    5.0            Alva R.
# 103358    5.0             warren
# 103359    5.0               Gary
# 103360    5.0              Alejo
# 103361    1.0     Kathy Browning
# 103362    5.0        Joy S Greer
# 103363    5.0      Karen Shpiece
# 103364    4.0          Budsparks
# 103365    3.0              Jason
# 103366    5.0    Amazon Customer
# 103367    5.0   Josephine Hardie
#
# [103249 rows x 8 columns]

# %%
import pandas as pd
from nltk import sent_tokenize
import re

def make_same_feature(text):
    
    # 각각의 feature 별 동의어를 대표명으로 정리
    text=re.sub('resolution|pixel|megapixel', 'pixel', text)
    text=re.sub('lens|wide\sangle|normal\srange', 'lens', text)
    text=re.sub('optical|zoom|optical\szoom|digital\szoom', 'optical', text)
    text=re.sub('memory|megabytes|MB', 'memory', text)
    text=re.sub('burst|continuous|shutter|recovery|motion|sport', 'burst', text)
    text=re.sub('battery|batteries|power', 'battery', text)
    text=re.sub('focus|exposure|manual|iso', 'focus', text)
    text=re.sub('LCD|screen', 'LCD', text)
    text=re.sub('compression|compress|jpeg', 'compression', text)
    text=re.sub('flash|light', 'flash', text)
    return text

def pre_processing(data):
    # score 변수를 정리하여 현재 점수만을 표현하도록 변경
    data['score'] = data['score'].apply(lambda x : x.split(' ')[0])
    data = data.fillna(1)
    result = []
    for i in range(len(data)):
        # 아래 for문에서 딕셔너리를 만드릭 위해 각각의 데이터를 변수로 저장
        product = data.loc[i, 'product_name']
        date = data.loc[i, 'review_date']
        score = data.loc[i, 'score']
        user = data.loc[i, 'user']
        text = data.loc[i, 'review']
        asin = data.loc[i, 'asin']
        item_model_no = data.loc[i, 'item_model_no']
        
        Sentences_list = sent_tokenize(text)
        for txt in Sentences_list:
            dict_n = {
                'product' : product,
                'date' : date,
                'score' : score,
                'user' : user,
                'review' : txt,
                'asin' : asin,
                'item_model_no' : item_model_no
            }
            result.append(dict_n)
    
    # 데이터프레임으로 형식 전환
    df = pd.DataFrame(result)
    
    # 각 feature별 동의어 처리 함수 사용
    df['review'] = df['review'].apply(make_same_feature)
    
    # feature가 들어있는 문장만 별로로 출력
    # str은 앞의 시리즈 데이터를 문자열로 처리하기 위한 변환식
    # contains는 데이터 내에 패턴이 존재하기만 하면 위치에 상관없이 True 값 출력
    df = df[df.review.str.contains('pixel|lens|optical|memory|burst|battery|focus|LCD|compression|flash')== True]

    return df

# %%
data_pp=pre_processing(data)
data_pp
# Out:
# C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-7bdee20e80de> in <module>
# ----> 1 data_pp=pre_processing(data)
#       2 data_pp
#
# <ipython-input-15-e5e435117de2> in pre_processing(data)
#      26     for i in range(len(data)):
#      27         # 아래 for문에서 딕셔너리를 만드릭 위해 각각의 데이터를 변수로 저장
# ---> 28         product = data.loc[i, 'product_name']
#      29         date = data.loc[i, 'review_date']
#      30         score = data.loc[i, 'score']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
aa = data_pp[data_pp.review.str.contains('pixel|lens|optical|memory|burst|battery|focus|LCD|compression|flash')== True]
aa

# %%
print(data_pp.loc[111,'review'])
print(data_pp.loc[362,'review'])
print(data_pp.loc[765,'review'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 111
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-063df0950853> in <module>
# ----> 1 print(data_pp.loc[111,'review'])
#       2 print(data_pp.loc[362,'review'])
#       3 print(data_pp.loc[765,'review'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 111
