# %% [markdown]
# # 공공데이터 - 대기오염 조회

# %%
import requests
from bs4 import BeautifulSoup
import urllib

BASE_ENDPOINT = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/' #개발환경 url
#일반 기본키는 utf-8로 인코딩이 되어 있음. 
#MY_API_KEY를 문자열로 params에 보낼 때 또 한번 인코딩이 들어감. 2번 인코딩이 되면서 문자가 달라짐.
MY_API_KEY = 'NTVlZ8j1a5MywJvsCoQXfOig5ms%2B5Z%2Fu%2BpTKlFRdUk3DdDiYLaf1w9F9g9H1dV3ft4Stnr7457ybjY0fRAH1WA%3D%3D'

# 위 에러를 없애기 위해 decode 진행
MY_API_KEY = urllib.parse.unquote(MY_API_KEY)
MY_API_KEY
# Out:
# 'NTVlZ8j1a5MywJvsCoQXfOig5ms+5Z/u+pTKlFRdUk3DdDiYLaf1w9F9g9H1dV3ft4Stnr7457ybjY0fRAH1WA=='

# %% [markdown]
# # 측정소별 실시간 측정정보 조회

# %%
#명세문서에 들어가서  getMsrstnAcctoRltmMesureDnsty 확인
#url end-point url 가져오기

OPERATION_NAME = 'getMsrstnAcctoRltmMesureDnsty'

# %%
endpoint = urllib.parse.urljoin(BASE_ENDPOINT, OPERATION_NAME)
endpoint
# Out:
# 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'

# %%
params = {
    'ServiceKey' : MY_API_KEY,
    'numOfRows' : 10,
    'pageNo' : 1,
    'stationName' : '강남구',
    'dataTerm' : 'DAILY',
    'ver' : '1.3'
}

# %%
resp = requests.get(endpoint, params)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n\r\n\r\n\r\n\r\n<response>\r\n\t<header>\r\n\t\t<resultCode>00</resultCode>\r\n\t\t<resultMsg>NORMAL SERVICE.</resultMsg>\r\n\t</header>\r\n\t<body>\r\n\t\t<items>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2019-06-10 13:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0</mangName>\r\n                    \r\n\t\t\t\t\t<so2Value>0.005</so2Value>\r\n\t\t\t\t\t<coValue>0.2</coValue>\r\n\t\t\t\t\t<o3Value>0.023</o3Value>\r\n\t\t\t\t\t<no2Value>0.013</no2Value>\r\n\t\t\t\t\t<pm10Value>-</pm10Value>\r\n\t\t\t\t\t\r\n                        <pm10Value24>7</pm10Value24>\r\n                    \r\n\t\t\t\t\t\r\n                        <pm25Value>2</pm25Value>\r\n                    \r\n                    \r\n                        <pm25Value24>3</pm25Value24>\r\n                    \r\n\t\t\t\t\t<khaiValue>38</khaiValue>\r\n\t\t\t\t\t<khaiGrade>1</khaiGrade>\r\n\t\t\t\t\t<so2Gr
# ...

# %%
resp.request.url
# Out:
# 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?ServiceKey=NTVlZ8j1a5MywJvsCoQXfOig5ms%2B5Z%2Fu%2BpTKlFRdUk3DdDiYLaf1w9F9g9H1dV3ft4Stnr7457ybjY0fRAH1WA%3D%3D&numOfRows=10&pageNo=1&stationName=%EA%B0%95%EB%82%A8%EA%B5%AC&dataTerm=DAILY&ver=1.3'

# %%
soup = BeautifulSoup(resp.content)
soup
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><response>
# <header>
# <resultcode>00</resultcode>
# <resultmsg>NORMAL SERVICE.</resultmsg>
# </header>
# <items>
# <item>
# <datatime>2019-06-10 13:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.005</so2value>
# <covalue>0.2</covalue>
# <o3value>0.023</o3value>
# <no2value>0.013</no2value>
# <pm10value>-</pm10value>
# <pm10value24>7</pm10value24>
# <pm25value>2</pm25value>
# <pm25value24>3</pm25value24>
# <khaivalue>38</khaivalue>
# <khaigrade>1</khaigrade>
# <so2grade>1</so2grade>
# <cograde>1</cograde>
# <o3grade>1</o3grade>
# <no2grade>1</no2grade>
# <pm10grade>1</pm10grade>
# <pm25grade>1</pm25grade>
# <pm10grade1h></pm10grade1h>
# <pm25grade1h>1</pm25grade1h>
# </item>
# <item>
# <datatime>2019-06-10 12:00</datatime>
# <mangname>도시대기</mangname>
# <so2value>0.005</so2value>
# <covalue>0.2</covalue>
# <o3value>0.019</o3value>
# <no2value>0.014</no2value>
# <pm10value>7</pm10value>
# <pm10value24>8</pm10value24>
# ...

# %% [markdown]
# # json으로 (&_returnType=json)

# %%
params = {
    'ServiceKey' : MY_API_KEY,
    'numOfRows' : 10,
    'pageNo' : 1,
    'stationName' : '강남구',
    'dateTerm' : 'DAILY',
    'ver' : '1.3',
    '_returnType' : 'json'
}

#params['+returnType'] = 'json'

# %%
resp = requests.get(endpoint, params)
resp

# %%
resp.content

# %%
resp.json()

# %% [markdown]
# #

# %% [markdown]
# # 통합대기환경지수 측정소 목록조회

# %%
import requests
from bs4 import BeautifulSoup
import urllib

BASE_ENDPOINT = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/' #개발환경 url
#일반 기본키는 utf-8로 인코딩이 되어 있음. 
#MY_API_KEY를 문자열로 params에 보낼 때 또 한번 인코딩이 들어감. 2번 인코딩이 되면서 문자가 달라짐.
MY_API_KEY = 'NTVlZ8j1a5MywJvsCoQXfOig5ms%2B5Z%2Fu%2BpTKlFRdUk3DdDiYLaf1w9F9g9H1dV3ft4Stnr7457ybjY0fRAH1WA%3D%3D'

# 위 에러를 없애기 위해 decode 진행
MY_API_KEY = urllib.parse.unquote(MY_API_KEY)

# %%
OPERATION_NAME = 'getUnityAirEnvrnIdexSnstiveAboveMsrstnList'
endpoint = urllib.parse.urljoin(BASE_ENDPOINT, OPERATION_NAME)
params = {
    'ServiceKey' : MY_API_KEY,
    'numOfRows' : 10,
    'pageNo' : 1,
    '_returnType' : 'json'
}
#params['_returnType'] = 'json'
resp = requests.get(endpoint, params)
resp.json()
# Out:
# {'list': [{'_returnType': 'json',
#    'addr': '서울 서초구 강남대로 201서초구민회관 앞 중앙차로',
#    'districtNum': '',
#    'dmX': '',
#    'dmY': '',
#    'item': '',
#    'mangName': '',
#    'map': '',
#    'numOfRows': '10',
#    'oper': '',
#    'pageNo': '1',
#    'photo': '',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sggName': '',
#    'sidoName': '',
#    'stationCode': '',
#    'stationName': '강남대로',
#    'tm': 0,
#    'tmX': '',
#    'tmY': '',
#    'totalCount': '',
#    'umdName': '',
#    'ver': '',
#    'vrml': '',
#    'year': ''}],
#  'parm': {'_returnType': 'json',
#   'coGrade': '',
#   'coValue': '',
#   'dataTerm': '',
#   'dataTime': '',
#   'khaiGrade': '',
#   'khaiValue': '',
#   'mangName': '',
#   'no2Grade': '',
#   'no2Value': '',
#   'numOfRows': '10',
#   'o3Grade': '',
#   'o3Value': '',
#   'pageNo': '1',
#   'pm10Grade': '',
#   'pm10Grade1h': '',
#   'pm10Value': '',
#   'pm10Value24': '',
#   'pm25Grade': '',
# ...

# %%
OPERATION_NAME = 'getUnityAirEnvrnIdexSnstiveAboveMsrstnList'
endpoint = urllib.parse.urljoin(BASE_ENDPOINT, OPERATION_NAME)
params = {
    'ServiceKey' : MY_API_KEY,
    'numOfRows' : 10,
    'pageNo' : 1,
    '_returnType' : 'json'
}

resp = requests.get(endpoint, params)
print(resp.content)
soup = BeautifulSoup(resp.content)
print(soup)
# Out:
# b'{"list":[{"_returnType":"json","addr":"\xec\x84\x9c\xec\x9a\xb8 \xec\x84\x9c\xec\xb4\x88\xea\xb5\xac \xea\xb0\x95\xeb\x82\xa8\xeb\x8c\x80\xeb\xa1\x9c 201\xec\x84\x9c\xec\xb4\x88\xea\xb5\xac\xeb\xaf\xbc\xed\x9a\x8c\xea\xb4\x80 \xec\x95\x9e \xec\xa4\x91\xec\x95\x99\xec\xb0\xa8\xeb\xa1\x9c","districtNum":"","dmX":"","dmY":"","item":"","mangName":"","map":"","numOfRows":"10","oper":"","pageNo":"1","photo":"","resultCode":"","resultMsg":"","rnum":0,"serviceKey":"","sggName":"","sidoName":"","stationCode":"","stationName":"\xea\xb0\x95\xeb\x82\xa8\xeb\x8c\x80\xeb\xa1\x9c","tm":0,"tmX":"","tmY":"","totalCount":"","umdName":"","ver":"","vrml":"","year":""}],"parm":{"_returnType":"json","coGrade":"","coValue":"","dataTerm":"","dataTime":"","khaiGrade":"","khaiValue":"","mangName":"","no2Grade":"","no2Value":"","numOfRows":"10","o3Grade":"","o3Value":"","pageNo":"1","pm10Grade":"","pm10Grade1h":"","pm10Value":"","pm10Value24":"","pm25Grade":"","pm25Grade1h":"","pm25Value":"","pm25Value24":""
# ...

# %% [markdown]
# # 함수로 정리하기

# %%
import requests
import urllib
from bs4 import BeautifulSoup

BASE_ENDPOINT = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/' #개발환경 url

def get_measure(serviceKey, numOfRows, pageNo,stationName, dataTerm, ver, returnType):
    OPERATION_NAME = 'getMsrstnAcctoRltmMesureDnsty'
    endpoint = urllib.parse.urljoin(BASE_ENDPOINT, OPERATION_NAME)
    
    params = {
        'serviceKey' : serviceKey,
        'numOfRows' : numOfRows,
        'pageNo' : pageNo,
        'stationName' : stationName,
        'dataTerm' : dataTerm,
        'ver' : ver,
        '_returnType' : returnType
    }
    
    
    resp = requests.get(endpoint, params)
    if resp.status_code == 200:
        return resp.content
    
    
    return False

# %%
measure_list = get_measure(MY_API_KEY, 100, 1, '강남구', 'month', '1.0', 'json')

# %%
import json

# %%
json_list = json.loads(measure_list)
json_list
# Out:
# {'list': [{'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.2',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 11:00',
#    'khaiGrade': '1',
#    'khaiValue': '27',
#    'mangName': '도시대기',
#    'no2Grade': '1',
#    'no2Value': '0.015',
#    'numOfRows': '10',
#    'o3Grade': '1',
#    'o3Value': '0.016',
#    'pageNo': '1',
#    'pm10Grade': '1',
#    'pm10Grade1h': '1',
#    'pm10Value': '6',
#    'pm10Value24': '8',
#    'pm25Grade': '1',
#    'pm25Grade1h': '1',
#    'pm25Value': '2',
#    'pm25Value24': '4',
#    'resultCode': '',
#    'resultMsg': '',
#    'rnum': 0,
#    'serviceKey': '',
#    'sidoName': '',
#    'so2Grade': '1',
#    'so2Value': '0.004',
#    'stationCode': '',
#    'stationName': '',
#    'totalCount': '',
#    'ver': ''},
#   {'_returnType': 'json',
#    'coGrade': '1',
#    'coValue': '0.3',
#    'dataTerm': '',
#    'dataTime': '2019-06-10 10:00',
#    'khaiGrade': '1',
#    'khaiValue': '27',
#    'mangName': '도시대기',
# ...

# %%
temp_dict = {
    'name' : '동훈',
    'location' : 'seoul',
    'friend' : ['영수', '철수', '영희']
}

file = json.dumps(temp_dict)

# %%
file
# Out:
# '{"name": "\\ub3d9\\ud6c8", "location": "seoul", "friend": ["\\uc601\\uc218", "\\ucca0\\uc218", "\\uc601\\ud76c"]}'
