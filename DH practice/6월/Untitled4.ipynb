# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# %matplotlib qt

# %%
plt.plot([1,2,3])
plt.show()

# %%
# %matplotlib inline

# %%
x = np.arange(-5, 5, .1)
y1 = 0.3*(x-5)**2 + 1
y2 = -1.5*x + 3
y3 = np.sin(x)**2
y4 = 10*np.exp(-x) + 1

# 2 x 2 행렬로 나누고 위치조정
plt.subplot(2, 2, 1)
plt.plot(x, y1)

plt.subplot(2,2,2)
plt.plot(x, y2)

plt.subplot(2,2,3)
plt.plot(x, y3)




plt.show()

# %%
x = np.linspace(-4, 4,100) # [-4, 4] 범위에서 100개의 값 생성
y1 = x**3  
y2 = 10*x**2 - 2

plt.plot(x, y1, x, y2)
plt.show()

# %%
from sklearn.datasets import make_regression #가상의 회귀분석용 데이터 생성
from sklearn.linear_model import LinearRegression #LinearRegression
from sklearn.model_selection import train_test_split #Trainset, Testset 분리

X, y = make_regression(n_samples= 50, n_features= 30, bias=  10, noise= 10) 
print('Input_feature:\n {}\nTarget_value: \n{} '.format(X[:5], y[:5]))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# Linear Regression 클래스 객체 생성 
model = LinearRegression() # fit_intercept = 상수항 유무 결정 

# fit 메서드로 모형 추정 (오그멘테이션은 자동으로 수행) 
model_lr = model.fit(X_train, y_train)

print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# Input_feature:
#  [[-2.60748693  2.46731252  0.74260603 -0.18378446  1.48859908  1.67503603
#   -0.24410632 -0.33491897 -0.15470855  0.55604367  0.77635124 -1.03015978
#    1.02131959  0.51355874 -0.28079334 -1.15571612  0.28748258 -0.08484594
#   -2.06779043  0.41441999 -1.46347088 -0.43533244  2.09531716 -0.23277572
#   -0.85969962 -1.06563646 -1.36558737  0.04286918 -0.81856826 -0.43043989]
#  [-0.12556819  0.02903186  0.88877048  0.06957145  0.69398018  0.48145807
#   -2.33494296  0.11819539  1.10185831 -1.53114229  0.73388165 -0.79059
#   -0.54794848  1.87377522 -0.8506502  -0.17580946 -1.8237348  -0.14705119
#    0.16308278 -0.9095879  -0.71139612  1.87625631 -0.89426139 -0.37079229
#    0.79888618 -1.06907859 -0.6521719  -0.12609028  0.50891252  0.68782467]
#  [-0.48888348  1.56964959 -0.82683376 -0.19454192 -1.19220182 -1.13262918
#   -1.55871749  1.88007597  0.7599806  -0.28451132 -0.06140009 -1.12512106
#   -0.1412448   1.76140912  1.2042419  -0.59951412 -0.35177619 -0.41642868
#   -0.24611749  2.21251677 -0.3373955  -0.7891684   0.68368125 -0.08549227
#    1.33128243 -0.99520494 -0.41378541  0.60127132  1.10978349  1.18927167]
#  [-1.14243939  0.66983588 -0.89102823  0.23729118 -0.76971904  0.26815108
#   -1.31558029 -0.13278062 -0.82883546  0.5962861   0.41371615  1.78575627
#    1.15654698  1.98420994 -0.52998076  0.94090125  0.31380514 -0.57181017
#    1.77347959 -0.01190534 -1.78502689 -0.10035406  0.25344154 -0.69479623
#   -0.87127309  0.35021752 -0.26993163 -0.74793341  0.94976023  0.20383402]
#  [ 0.19543015  1.5672142  -1.99391143 -0.32590937 -1.25934612  0.06304685
#    0.84437574  0.89573794  0.75214714 -0.69402672 -0.81293028  0.5934836
#    2.77831423 -1.00593446  0.61511981 -0.3986261   0.07075765  0.58602308
#   -0.7899747   0.03658937 -0.04352655 -1.49971718  0.94117122 -1.30897905
#    0.29934629 -0.96535662 -0.75781828 -0.34409599 -0.28302378  0.63815445]]
# Target_value:
# [ -42.30165694  -55.07109357  -83.54491413 -145.19810227 -196.63253644]
# 0.9987955895338406
# 0.9956269268506776

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

X, y = make_regression(n_samples=1000, n_features=50, bias=100, noise=100)

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)

# %%
# Ridge Regression 클래스 객체 생성
model = Ridge(alpha=0.1) 
# fit 메서드로 모형 추정 (오그멘테이션은 자동으로 수행)
model_lr = model.fit(X_train, y_train)

print('weight: ', model_lr.coef_)
print('bias: ', model_lr.intercept_)
# Out:
# weight:  [-5.53278230e-01 -3.90786092e+00  2.81264637e+00 -2.48862578e+00
#  -2.37718273e+00  4.64588387e+00 -5.74644131e+00  2.22271564e+00
#  -2.89582841e+00  3.34556813e+00  7.69261038e+01  7.23451674e+01
#  -3.94938085e-01 -6.38438842e-01  2.90121138e+01  1.02114562e+00
#   6.25268202e+00  9.26852669e+00 -7.07237567e-01  7.81955352e+01
#   4.21174108e+01  5.85520476e+01  6.29298000e-02 -1.59707271e+00
#  -3.48397991e+00 -7.50727870e-02  5.82185921e+00 -9.96944969e+00
#   1.04239636e+00  7.38180874e+01 -1.64487500e+00  5.91053700e+00
#  -7.38550036e+00  2.50743887e+00  1.28802148e+01  1.34690797e+00
#  -1.24091231e+00  8.93165971e+01  8.22659371e-01  3.16233964e+00
#  -7.82744457e+00 -8.80498348e-01  1.31143289e-01  3.10361600e+00
#  -4.57731091e+00 -5.91642069e+00  3.36488431e+00 -1.31147628e+00
#  -1.10568298e+00 -1.79730138e+00]
# bias:  103.47901299258261

# %%
model.score(X_train, y_train)
# Out:
# 0.8003733520752271

# %%
model.score(X_test, y_test)
# Out:
# 0.711273307737555
