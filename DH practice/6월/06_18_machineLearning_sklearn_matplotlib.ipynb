# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver?query=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&where=news&ie=utf8&sm=nws_hty'

resp = requests.get(url)
soup = BeautifulSoup(resp.content)

l = soup.find('div', id ='main_pack').find('li', class_ = 'txt_sinfo')
print(l)
# Out:
# None

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X, y = make_regression(n_samples = 1000, n_features = 1, bias = 10, noise = 1)
#feature = 
print('input_feature:\n {}7nTarget_value: \n{}'.format(X[:5], y[:5]))
# Out:
# input_feature:
#  [[ 1.5497096 ]
#  [ 1.25920598]
#  [ 0.90205607]
#  [-1.20167183]
#  [-0.15897369]]7nTarget_value:
# [ 161.3680244   134.30953165   96.85514706 -106.79340709   -6.75181647]

# %%
print(type(X), type(y))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(X[:, 0],y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2 , shuffle = True)

# %%
X_train
# Out:
# array([[ 1.45255103e+00],
#        [ 7.85462170e-01],
#        [ 1.61459580e+00],
#        [-1.74660867e+00],
#        [ 4.28347331e-01],
#        [ 1.85022601e+00],
#        [ 7.20165608e-01],
#        [ 8.24654155e-02],
#        [-7.61150142e-01],
#        [-1.47593952e+00],
#        [-9.33715321e-01],
#        [ 1.61578595e+00],
#        [-1.39319686e-01],
#        [-2.32882009e-01],
#        [ 8.69811755e-01],
#        [-7.57363240e-01],
#        [-1.92378956e+00],
#        [ 1.76729149e+00],
#        [-6.51719564e-01],
#        [ 1.40473738e-01],
#        [-9.23046834e-01],
#        [-4.11270808e-01],
#        [ 4.34628931e-01],
#        [ 5.84801755e-01],
#        [ 1.02534311e-03],
#        [-1.39915606e+00],
#        [-5.03658014e-02],
#        [-1.22368763e+00],
#        [ 1.36287867e+00],
#        [-7.04356748e-01],
#        [ 9.95941219e-01],
#        [-1.05859432e+00],
#        [-3.82924102e-02],
#        [ 1.54945131e-01],
#        [ 1.32842455e-02],
# ...

# %%
X_test
# Out:
# array([[-0.24262541],
#        [ 0.1700031 ],
#        [-0.01232895],
#        [-0.27676176],
#        [ 0.96725843],
#        [-0.36016435],
#        [-0.48716546],
#        [ 2.18696182],
#        [-0.14667654],
#        [-0.96825299],
#        [ 0.80762944],
#        [-0.33541123],
#        [-1.37418064],
#        [ 0.86460523],
#        [-0.15630656],
#        [ 0.15802145],
#        [-1.14295193],
#        [-0.39834748],
#        [-0.29078465],
#        [ 0.5652704 ],
#        [ 0.90767904],
#        [-0.27215986],
#        [ 0.05134835],
#        [-1.09863648],
#        [ 0.58118904],
#        [ 0.92676513],
#        [-0.22222569],
#        [-2.72022666],
#        [ 0.0093073 ],
#        [-0.07354578],
#        [ 0.12760807],
#        [-1.57865113],
#        [ 2.2120014 ],
#        [ 0.38432235],
#        [-0.96572189],
#        [-0.73451082],
#        [-0.42515201],
#        [ 2.51245674],
#        [ 0.88828683],
#        [ 1.16975469],
#        [-0.99292581],
# ...

# %%
y_test
# Out:
# array([  -8.34648615,   23.04663712,    9.51845602,  -11.06992014,
#          83.45354574,  -15.41905225,  -25.54153373,  173.53890412,
#          -1.04769855,  -62.68424723,   70.1167515 ,  -14.84290176,
#         -91.82043632,   73.33383859,   -1.76016675,   20.41442309,
#         -73.45013815,  -20.02697818,  -10.57689919,   49.68379744,
#          76.82234673,   -8.74730265,   12.6106185 ,  -71.17502168,
#          53.07853693,   79.04040362,   -5.60691394, -192.72255564,
#          10.31213225,    4.67518969,   20.51004641, -106.44615777,
#         175.28093611,   38.90250537,  -61.97561392,  -43.66690263,
#         -20.94445562,  195.35309492,   74.84789361,   98.13980181,
#         -63.31961376,  163.19615814,  -60.06866966,  -64.27902395,
#           7.94232065,   -2.20945367,  119.83010502,   46.79127259,
#          50.86913122,   -5.82147768,  -86.24076465,  -78.71200867,
#          -8.04987593,   66.3461652 ,  124.93970522,  -30.37845583,
# ...

# %%
y_train
# Out:
# array([ 1.18671947e+02,  6.93186203e+01,  1.29236818e+02, -1.20192963e+02,
#         4.17494650e+01,  1.46910878e+02,  6.39389347e+01,  1.63013986e+01,
#        -4.60494717e+01, -9.85776329e+01, -5.85279596e+01,  1.27813949e+02,
#        -1.38177552e+00, -7.51145492e+00,  7.51801667e+01, -4.55224163e+01,
#        -1.32004082e+02,  1.40696296e+02, -3.71384767e+01,  2.00534540e+01,
#        -5.81226849e+01, -2.07490551e+01,  4.03842892e+01,  5.32726505e+01,
#         9.38604695e+00, -9.38702445e+01,  6.85045969e+00, -8.00295115e+01,
#         1.10870795e+02, -4.25986400e+01,  8.39809446e+01, -6.82655418e+01,
#         7.76351738e+00,  2.16479927e+01,  1.07987518e+01, -9.23383881e+01,
#         3.47418945e+01, -6.81127953e+01, -4.03877057e+01,  3.09182186e+01,
#        -5.09883778e+01,  5.06311713e+01, -1.19408763e+02, -1.07719031e+02,
#         1.24328025e+02,  3.89090026e+00, -6.01276724e+01, -5.66861023e+01,
# ...

# %%
#Linear Regression 클래스 객체 생성
model = LinearRegression()

#fit 메서드로 모형 추정

model_lr = model.fit(X_train, y_train)

print('weight: ', model_lr.coef_)
print('bias: ', model_lr.intercept_)
# Out:
# [74.07954143]
# weight:  [74.07954143]
# bias:  10.010626182744037

# %%
model.score(X_train, y_train)
# Out:
# 0.9998058746415424

# %%
model.score(X_test, y_test)
# Out:
# 0.9998263165469844

# %%
import numpy as np
model.predict(np.array([3,5]).reshape(2,1))
# Out:
# array([232.24925046, 380.40833331])

# %% [markdown]
# # RigidRegression

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import RigidRegression
from sklearn.model_selection import train_test_split

X, y = make_regression(n_samples = 10000, n_feature = 1000, bias = 10, noise = 100)
X_train, x_test, y_train, y_text = train_test_split(X, y, shuffle = True)

#Ridge Regresssion
model = Ridge(alpha = 0.1)

model_lr = model.fit(X_train, y_train)

print('weight: ', model_lr.coef_)
print('bias: ', model.intercept_)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-139-1b2fa07b44db> in <module>
#       1 from sklearn.datasets import make_regression
# ----> 2 from sklearn.linear_model import RigidRegression
#       3 from sklearn.model_selection import train_test_split
#       4
#       5 X, y = make_regression(n_samples = 10000, n_feature = 1000, bias = 10, noise = 100)
#
# ImportError: cannot import name 'RigidRegression' from 'sklearn.linear_model' (C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\sklearn\linear_model\__init__.py)

# %% [markdown]
# # Lasso Regresssion

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LassoRegression
from sklearn.model_selection import train_test_split
