# %% [markdown]
# # 단어 찾으면 해당 단어가 있는 문장 불러오기

# %%
#the simpsons
#american horror story
#how i met your mother
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

#전역 변수
url = 'https://www.springfieldspringfield.co.uk/episode_scripts.php?'
script_list = []   #다른 함수에서도 써야하기 때문에 전역변수로 선언
episode_list = []

#입력 받은 값에서 띄어쓰기가 있는 경우 '-'로 변환
def replace_space(series_name):  
    
    series_name = series_name.replace(" ", "-") #띄어쓰기는 url주소에 쓰이기 위해서 '-'로 변환
    series_name.lower()    #소문자로 바꾸기
    return series_name



#대본 크롤링
def script_crawling(series_name):
    params = {
        'tv-show' : series_name
    }

    resp = requests.get(url, params = params)
    soup = BeautifulSoup(resp.content, 'html.parser')
    
    find_frame = soup.find('div', class_ = 'main-content-left')           #가장 바깥 프레임 설정
    find_seasons = find_frame.find_all('div', class_ = 'season-episodes') #모든 시즌 가져오기
                                                                         #find_seasons[0] = season1

    url_list = []                                     #각 에피소드들의 주소를 담을 리스트
    url_base = 'https://www.springfieldspringfield.co.uk/'  
    for season in find_seasons:                            
        #에피소드 태그 추출               
        a_tags = season.find_all('a')    
                                      
        for a in a_tags:
            url_tag = a.attrs['href']                #에피소드 별 주소 추출            
            url_tag = url_base + url_tag             # 대본으로 가는 url 합치기        
            url_list.append(url_tag)                 #에피소드 대본 url a_tag_list에 넣기            

    print(url_list)

    #https://www.springfieldspringfield.co.uk/view_episode_scripts.php?tv-show=breaking-bad&episode=s01e01  's01e01' 만 빼오기    
    for i in url_list:    
        episode = i[-5:] 
        episode_list.append(episode)
    print(episode_list)
    
    #에피소드별 url에 접속 후 대본 가져오기

    count = 0
    for script_url in url_list:           #seasons_list 각 인덱스에 있는 url에 접속
        script_resp = requests.get(script_url)
        script_soup = BeautifulSoup(script_resp.content, 'html.parser')
        script_list.append(script_soup.find('div', class_ = 'scrolling-script-container').text)  #대본 페이지 본문 긁어 오기
        
        #제한 설정: 10개 에피소드 긁어오기
        count += 1
        if count == 10:
            break
#script crwaling end 
            
   
#텍스트 파일 하나로 몰아넣기
def save_to_txt(series_name):
    # 처음에 입력 받은 이름으로 파일 저장하기
    file_name = series_name + '_script.txt'
    print(file_name)
    count = 0
    with open(file_name, 'w', 1, 'utf-8') as f:   #'cp949' codec can't encode character '\xe8' in position 11518: 
                                                       #illegal multibyte sequence 에러 때문에 'utf-8' 인코딩 수정
        f.write('%s\n' % series_name)              # 미드 이름
        for scripts in script_list:                #해당 시즌 모든 에피소드 텍스트 파일에 입력
            f.write('\n-----------------------------------%s' % episode_list[count])
            f.write('\n%s' % scripts)
            count += 1            

#미드 이미지 가져오기/et(img_url)
def get_img(series_name):

    driver_path = 'C:\\Users\\15Z970-GA5BK\\Downloads\\chromedriver.exe'
    driver = webdriver.Chrome(driver_path)
    
    driver.get('https://www.google.com')
    driver.implicitly_wait(10)
    search_input = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div/div[1]/div/div[1]/input')
    search_input.send_keys(series_name)

    search_btn = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div/div[3]/center/input[1]').click()
    driver.implicitly_wait(10)
    image_btn = driver.find_element_by_link_text('이미지').click()
    
    #구글 이미지 
    #다음 페이지 이미지 불러오기
    img_count = 0   
    img_url_list = []
    while img_count < 40:
        img_next_url = 'https://www.google.com/search?q=' + series_name + \
                         '&biw=1036&bih=674&gbv=1&tbm=isch&ei=jWv6XKqsLo3VmAXk8ILQBg&start=' + str(img_count)
        # url에서 'start=' 값이 20씩 늘어날 때마다 다음 페이지로 넘어감
        resp3 = requests.get(img_next_url)
        soup3 = BeautifulSoup(resp3.content, 'html.parser')
        find_img = soup3.find('table', class_ = 'images_table')
        find_next_img = find_img.find_all('tr')
        for td in find_next_img:
            img_tag = td.find_all('img')
            for i in img_tag:
                img_src = i.attrs['src']
                img_url_list.append(img_src) #기존 img_url_list에 추가로 append
        img_count += 20
    #image source에 접근한 후 이미지 다운로드

    
    # 요기 이상함 count = 1 위치만 바꿧는데 매우 이상해짐
    count = 0
    while count <= 10:
        for i in img_url_list:
            count += 1
            img_url = i
            resp = requests.get(i)
            file_name = series_name  + str(count) + '.jpeg'  #번호 올리면서 이미지 저장
        
            with open(file_name, 'wb') as f:
                f.write(resp.content)     
            
            

series = replace_space(input('원하는 미드를 입력하세요: '))

#script_crawling(series)

save_to_txt(series)
#get_img(series)
# Out:
# 원하는 미드를 입력하세요: friends
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-735ed254f8c0> in <module>
#     136
#     137 #save_to_txt(series)
# --> 138 get_img(series)
#
# <ipython-input-5-735ed254f8c0> in get_img(series_name)
#      90     driver.implicitly_wait(10)
#      91     search_input = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div/div[1]/div/div[1]/input')
# ---> 92     search_input.send_keys(series_name)
#      93
#      94     search_btn = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div/div[3]/center/input[1]').click()
#
# AttributeError: 'NoneType' object has no attribute 'send_keys'

# %%
def search_sentences(search_word):
    count = 1
    for i in range(len(script_list)):
        sentences = script_list[i].split('.')
        for sentence in sentences:
            if search_word in sentence:
                
                print(f'{count}: {sentence}.')
                count += 1

# %%
search_sentences(input('찾을 단어: '))
# Out:
# 찾을 단어: like
# 1:  Sounds like a date to me.
# 2:  You okay? I feel like someone pulled my intestine out of my mouth.
# 3:  I got freaked out, and it hit me: How much Barry looks like Mr.
# 4:  She really likes it when you rub her neck in the same spot.
# 5:  Love is sweet as summer showers Love is a wondrous work of art But your love Oh, your love, your love Is like a giant pigeon Crapping on my heart Thank you.
# 6:  That's like saying there's only one flavor of ice cream.
# 7:  You were like, what, 8? Welcome back to the world.
# 8: " If you feel like you have to make a Western omelet or something.
# 9:  Last night was like all my birthdays, both graduations.
# 10:  So, like, you guys all have jobs? Yeah, we all have jobs.
# 11:  You look like you slept with a hanger in your mouth.
# 12:  Well, it's like that.
# 13:  You mean, you know Paul like I know Paul? What? I take credit for Paul.
# 14:  Why would anybody do something like that? I assume we want an answer more sophisticated than: "To get you into bed.
# 15:  Is it me? Is it like I have some sort of beacon that only dogs.
# 16:  Would anybody like more coffee? You made it, or you're serving it? - I'm just serving it.
# 17:  like the comedian you have to sit through.
# 18:  And it's not that we don't like the comedian.
# 19:  Okay, they have issues like: "Gee, that glacier's getting kind of close.
# 20:  People like Ross need to shoot for the stars.
# 21:  like cows.
# 22:  - Identical? - People say we look alike.
# 23:  it kind of looks like an old potato.
# 24:  It's, like, dating language.
# 25:  You can smoke like this: - Chandler - Or hold it in your mouth.
# 26:  But if you spent it, it would be like shopping.
# 27:  Why should they meet him? I bring a guy home and they're like.
# 28:  I wish that once I'd date a guy they liked.
# 29:  Remember how much you all like me? Alan, this is everybody.
# 30:  - Know what I like most? - What? The way he makes me feel about myself.
# 31:  It was like he made us into a team.
# 32:  like this tiny little hitchhiker.
# 33:  Is it a little annoying? Or is it like when Phoebe chews her hair? Don't listen to him.
# 34:  Ever go out with a guy your friends really like? No.
# 35:  I'm going out with a guy my friends really like.
# 36:  Gee, you know, no one's ever put it like that before.
# 37:  So that's it? It's over? Just like that? You let your guard down.
# 38:  He could row like a Viking.
# 39:  You look like you're in a play.
# 40:  I mean, you've lost, like, a ton of weight.
# 41:  Carol was wearing boots just like those the night that we first.
# 42:  Hey, that woman's got an ass like Carol's.
# 43:  How was it with your friends? Okay, how would you like some Tiki Death punch? -What's that? -Well, it's rum and Okay.
# 44:  And it's not even for me! If that sounds like I'm okay, then tell them I'm okay.
# 45:  Monica, what is so amazing? I gave up, like, everything.
# 46:  And for what? -You are just like Jack.
# 47:  Now it's like.
# 48:  Yeah, like that's a word.
# 49:  But Monica, what if it doesn't come together? Pheebs? Well, because you just I don't like this question.
# 50:  You know, I feel like I've lost her.
# 51:  I' m gonna push you, okay? How about I push you like this? Now you're gonna be in a wheelchair the rest of your life, pally-wally.
# 52:  -Shut up! So, what do you think George is like? -I think he's shy.
# 53:  I think Joey's like a little kiddie ride.
# 54:  It's a little more complicated What is it, that she left you for another woman that likes women? Louder.
# 55:  Chandler, nobody likes breaking up with someone.
# 56:  She'd feel like we're ganging up on her.
# 57:  And not just at the fun stuff, but, like, talking too.
# 58:  She's like one of a kind, like a snowflake or.
# 59:  -Something else like a snowflake? -Yeah, yeah.
# 60:  You know, like a little fuzzy bear.
# 61:  What does Bob look like? Is he tall, short? Yep.
# 62:  It's like pulling off a Band-Aid.
# 63:  God, I'm gonna look like a big Marshmallow Peep! What am I doing? My father's right! I can't live on my own.
# 64:  Could we check it in the light, please? -Oh, my God! -What? Were we at the same table? It's like cocktails in Appalachia.
# 65:  -l' m out of here! -Wait! You like him.
# 66:  He likes you.
# 67:  -How do you do that? -It's like a gift.
# 68:  I'd like that! The clothes are clean.
# 69:  Except everything looks like jammies now.
# 70:  Did anybody else feel like peeling their skin off to have something else to do? Ross, 1 0:00.
# 71:  Is it? It feels like 2.
# 72:  -No, 1 0:00! -What? There's a beautiful woman at 8, 9, 1 0:00! Hello! She's amazing! She makes the women l dream about look like fat, bald men.
# 73:  He couldn't get a woman like that in a million years.
# 74:  What I wanted to say was would you like to go out with me? Thank you.
# 75:  " I like that better.
# 76:  Do you see anything here? -lt looks like a boat.
# 77:  How was your date, Chandler? It was unbelievable! I've never met anyone like her.
# 78:  His kids liked me better than him.
# 79:  There's a theory put forth by Richard Leakey Are we greeting each other this way now? I like it.
# 80:  But you know what? Just for fun Iet's see what it looked like in the old spot.
# 81:  Every single second is like that with Aurora.
# 82:  I would like to get this in one take.
# 83:  I think his butt would like to get the shot before lunch.
# 84:  So you' re not completely fulfilled by Rick, Ethan and myself? No, that's not exactly what I was Most women would kill for three guys like us.
# 85:  Well, part of me wants that  but it's like l' m two guys.
# 86:  No? What happened, big guy? Big guy? It felt like a "big guy" moment.
# 87:  Did it feel like your shot? Hard to tell.
# 88:  Would you like to call somebody? Yeah, about 300 guys I went to high school with.
# 89:  -Step back! -We have a winner! This must be what the fridge looks like with the door closed.
# 90:  -What? What? -Don't you hear that? See? -Would you like gum? -ls it sugarless? -Sorry, it's not.
# 91:  What? Looks like I was second to last.
# 92:  I don't know if you got that  but I would really like a copy of the tape.
# 93:  I told her you were seeing Bernie Spellman who also liked her.
# 94:  Women find you less threatening, they let their guards down you' re like a stealth heterosexual.
# 95:  Aunt Phylis is dead? Yeah, for like six years.
# 96:  Isn't this more about the fact that once you decide, it's like acknowledging Nana's actually gone? No, I really hate to shop.
# 97:  It looks like fun.
# 98:  I'd like that.
# 99:  If you were gonna set me up  I'd like to think it'd be with somebody like him.
# 100:  We ready to go? -Don't we look nice all dressed up? It's stuff like that, isn't it? -lt was a really beautiful service.
# 101:  Just that your coat sounds like Brent Musberger.
# 102:  " That sounds like Nana.
# 103:  Do you know what it's like to grow up with someone who is critical of every single thing you say? I can imagine.
# 104:  " You look just like your grandmother.
# 105:  It looks like a fun gang.
# 106:  So how's it going in Financial Services? It's like Mardi Gras without the papier-mache heads.
# 107:  I was thinking you look more like, Joey T ribbiani, man/woman.
# 108:  How can they do this? It's Thanksgiving! What if I cook dinner at my place? I'll make it just like Mom's.
# 109:  -What's it look like? -Kind of like a big face without skin.
# 110:  I'd just like to say I'm totally behind this experiment.
# 111:  In fact, I'd very much like to butter your head.
# 112:  Why do that? Because then they'd be just like my mom used to make it, before she died.
# 113:  Why do you guys have so many keys in there anyway? For an emergency just like this.
# 114:  -No Well, the turkey's burnt! Potatoes are ruined! Potatoes are ruined! Potatoes are ruined! Here we come Walking down the This doesn't smell like Mom's.
# 115:  This was nobody's first choice! Oh, really? So why was I busting my ass to make this delicious dinner? -You call that delicious? -You be quiet! Stop it! Stop it! Stop it! Now this feels like Thanksgiving.
# 116:  All right, I'd like to propose a toast.
# 117:  Guys, there's somebody I'd like you to meet.
# 118:  Is it something you'd like to share with the group? No.
# 119:  I said I liked her in Splash, but not Wall Street.
# 120:  David's, like, a scientist guy.
# 121:  -Me too! Did you ever see An Officer and a Gentleman? He's kind of like the guy I went to see that with.
# 122:  That would be great! But make sure it seems like you're there to see him.
# 123:  We've been back together for what -Iike 1 0 minutes, and -ls that all? It's like we were never apart.
# 124:  Looks like that no-date pact worked out.
# 125:  I don't feel like kissing anyone tonight.
