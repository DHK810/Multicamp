# %%
import os
import pandas as pd
BASE_DIR = os.getcwd()
DATASET_PATH = os.path.join(BASE_DIR, 'datasets\\201904') ## 'datasets\\201904'

file1 = os.path.join(DATASET_PATH, '2019-04-01.csv')
df = pd.read_csv(file1, error_bad_lines = False)
df
# Out:
# b'Skipping line 36560: expected 8 fields, saw 11\n'
#         2019-04-01  2142932948  C011020   남자상의  \
# 0       2019-04-01  1812194343  C013020    티셔츠
# 1       2019-04-01   954865871  C014010    아동복
# 2       2019-04-01   853175004  A021010     커피
# 3       2019-04-01   826899644  A019050     간장
# 4       2019-04-01  1095655438  L012010    면도기
# 5       2019-04-01   912133680  C011050   남자내의
# 6       2019-04-01   176168123  C013010     점퍼
# 7       2019-04-01   342609665  C011040   남자하의
# 8       2019-04-01   928928755  C021030    운동화
# 9       2019-04-01   814924610  E061100  습기제거제
# 10      2019-04-01  1983249606  C013020    티셔츠
# 11      2019-04-01   878389843  C012010   여자외의
# 12      2019-04-01  1126405207  C011040   남자하의
# 13      2019-04-01  1549553626  E061100  습기제거제
# 14      2019-04-01  1904504950  A017300     미역
# 15      2019-04-01  1073659289  C013010     점퍼
# 16      2019-04-01  1152942597  C014010    아동복
# 17      2019-04-01   943429570  C011020   남자상의
# ...

# %%
import os
import glob
import pandas as pd

    
BASE_DIR = os.getcwd()
DATASET_PATH = r'C:\Users\15Z970-GA5BK\Dropbox\Multicamp19_05_27\DH practice\datasets\201904'
DATASET_PATH
allFiles = glob.glob(DATASET_PATH + "/*.csv")
frame = pd.DataFrame()
list_ = []

for file_ in allFiles:
    df = pd.read_csv(file_,error_bad_lines = False , header=0)

    list_.append(df)
    
frame = pd.concat(list_, ignore_index = True)
frame
frame.tail()

# %%
import os
import glob
import pandas as pd

    
BASE_DIR = os.getcwd()
DATASET_PATH = r'C:\Users\15Z970-GA5BK\Dropbox\Multicamp19_05_27\DH practice\datasets\2019_05_31'
DATASET_PATH
allFiles = glob.glob(DATASET_PATH + "/*.csv")

# %% [markdown]
# # 연습문제 답

# %%
import os
import glob
import pandas as pd

BASE_DIR = os.getcwd()
DATASET_PATH = os.path.join(BASE_DIR, 'datasets\\201904') 
DATASET_PATH

initial_file = os.path.join(DATASET_PATH, '2019-04-01.csv')
o_df  = pd.read_csv((initial_file), header = None, error_bad_lines = False)
o_df.info()

# %%
for idx, x in enumerate(pd.date_range('2019-04-02', periods=3)):
    date = x.strftime('%Y-%m-%d')
    filename = "{}.csv".format(date)
    
    filepath = os.path.join(DATASET_PATH, filename)
    df = pd.read_csv(filepath, header = None, error_bad_lines = False)
    o_df = o_df.append(df)
    print(file)

# %%
o_df.head()

# %%
o_df.tail()

# %%
o_df.to_csv('완성본.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ea40b001174> in <module>
# ----> 1 o_df.to_csv('완성본.csv')
#
# NameError: name 'o_df' is not defined

# %%
df = pd.read_csv('완성본.csv', encoding = 'cp949' , index_col = 0)
