# %%
import quandl
df_gold = quandl.get('NBSC/A19011D_M')

# %%
df_gold
# Out:
#             Value
# Date
# 2016-02-29   53.3
# 2016-03-31   54.8
# 2016-04-30   55.0
# 2016-05-31   55.1
# 2016-06-30   55.2
# 2016-07-31   55.8
# 2016-08-31   56.4
# 2016-09-30   57.3
# 2016-10-31   58.2
# 2016-11-30   59.0
# 2016-12-31   58.2
# 2017-01-31   58.5
# 2017-02-28   60.0
# 2017-03-31   58.3
# 2017-04-30   56.6
# 2017-05-31   56.8
# 2017-06-30   58.7
# 2017-07-31   59.1
# 2017-08-31   59.5
# 2017-09-30   59.4
# 2017-10-31   57.0
# 2017-11-30   57.9
# 2017-12-31   58.7
# 2018-01-31   56.8
# 2018-02-28   58.2
# 2018-03-31   58.7
# 2018-04-30   58.4
# 2018-05-31   58.7
# 2018-06-30   57.9
# 2018-07-31   56.6
# 2018-08-31   57.0
# 2018-09-30   56.4
# 2018-10-31   56.4
# 2018-11-30   54.2

# %%
import matplotlib as plt
# %matplotlib inline

df_gold['USD (AM)'].plot()
