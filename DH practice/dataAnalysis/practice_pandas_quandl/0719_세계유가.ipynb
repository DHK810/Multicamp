# %%
import quandl
mydata = quandl.get('EIA/PET_RWTC_D')

# %%
mydata
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# 1986-01-09  26.03
# 1986-01-10  25.65
# 1986-01-13  25.08
# 1986-01-14  24.97
# 1986-01-15  25.18
# 1986-01-16  23.98
# 1986-01-17  23.63
# 1986-01-20  21.33
# 1986-01-21  20.61
# 1986-01-22  20.25
# 1986-01-23  19.93
# 1986-01-24  19.45
# 1986-01-27  20.87
# 1986-01-28  19.45
# 1986-01-29  19.61
# 1986-01-30  19.58
# 1986-01-31  18.95
# 1986-02-03  17.42
# 1986-02-04  15.58
# 1986-02-05  16.28
# 1986-02-06  16.60
# 1986-02-07  17.70
# 1986-02-10  16.78
# 1986-02-11  16.28
# 1986-02-12  15.74
# ...           ...
# 2019-06-21  57.35
# 2019-06-24  57.73
# 2019-06-25  57.63
# 2019-06-26  59.17
# 2019-06-27  59.18
# 2019-06-28  58.20
# 2019-07-01  58.91
# 2019-07-02  56.00
# 2019-07-03  57.06
# 2019-07-08  57.35
# 2019-07-09  57.57
# 2019-07-10  60.28
# 2019-07-11  59.93
# 2019-07-12  59.99
# 2019-07-15  59.30
# 2019-07-16  57.44
# 2019-07-17  56.50
# ...

# %%
mydata[mydata['Value'] == 55.67 | mydata['Value'] == 55.64]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in ror_(left, right)
#     190 def ror_(left, right):
# --> 191     return operator.or_(right, left)
#     192
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1803                 try:
# -> 1804                     result = libops.scalar_binop(x, y, op)
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.plot()

# %%
mydate = quandl.get('EIA/PET_RWTC_D', returns = 'numpy')
mydate
# Out:
# rec.array([('1986-01-02T00:00:00.000000000', 25.56),
#            ('1986-01-03T00:00:00.000000000', 26.  ),
#            ('1986-01-06T00:00:00.000000000', 26.53), ...,
#            ('2019-07-11T00:00:00.000000000', 59.93),
#            ('2019-07-12T00:00:00.000000000', 59.99),
#            ('2019-07-15T00:00:00.000000000', 59.3 )],
#           dtype=[('Date', '<M8[ns]'), ('Value', '<f8')])

# %%
import pandas as pd
oil_1986_2000 = mydata.loc['1986-01-02': '2000-12-31']
oil_2001_2019 = mydata.loc['2001-01-01': '2019-07-15']

# %%
oil_2001_2019
# Out:
#             Value
# Date
# 2001-01-02  27.29
# 2001-01-03  27.93
# 2001-01-04  27.95
# 2001-01-05  28.02
# 2001-01-08  27.44
# 2001-01-09  27.72
# 2001-01-10  29.42
# 2001-01-11  29.42
# 2001-01-12  30.07
# 2001-01-16  30.19
# 2001-01-17  29.77
# 2001-01-18  30.42
# 2001-01-19  32.12
# 2001-01-22  32.21
# 2001-01-23  31.66
# 2001-01-24  31.46
# 2001-01-25  31.61
# 2001-01-26  29.79
# 2001-01-29  29.07
# 2001-01-30  29.12
# 2001-01-31  28.62
# 2001-02-01  29.88
# 2001-02-02  31.27
# 2001-02-05  30.55
# 2001-02-06  30.27
# 2001-02-07  31.27
# 2001-02-08  31.57
# 2001-02-09  30.93
# 2001-02-12  30.52
# 2001-02-13  30.12
# ...           ...
# 2019-05-31  53.49
# 2019-06-03  53.25
# 2019-06-04  53.50
# 2019-06-05  51.57
# 2019-06-06  52.59
# 2019-06-07  53.95
# 2019-06-10  53.33
# 2019-06-11  53.30
# 2019-06-12  51.13
# 2019-06-13  52.38
# 2019-06-14  52.47
# 2019-06-17  51.94
# 2019-06-18  53.86
# 2019-06-19  53.74
# 2019-06-20  56.88
# 2019-06-21  57.35
# 2019-06-24  57.73
# ...

# %%
both_price = oil_1986_2000.join(oil_2001_2019, how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0c9d80a55829> in <module>
# ----> 1 both_price = oil_1986_2000.join(oil_2001_2019, how = 'inner')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6813         # For SparseDataFrame's benefit
#    6814         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6815                                  rsuffix=rsuffix, sort=sort)
#    6816
#    6817     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6828             return merge(self, other, left_on=on, how=how,
#    6829                          left_index=on is None, right_index=True,
# ...
