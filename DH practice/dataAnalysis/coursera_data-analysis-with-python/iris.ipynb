# %%
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# load dataset into Pandas DataFrame
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

# %%
df.target.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: target, dtype: int64

# %%
import seaborn as sns
#df['target'].replace('Iris-setosa', 1, inplace = True)
df['target'].replace('Iris-versicolor', 2, inplace = True)
df['target'].replace('Iris-virginica', 3, inplace = True)
#sns.regplot(x = 'sepal length', y = 'target', data = df)
#plt.ylim(0,)

# %%
df['target'] = df['target'].astype('int')

# %%
sns.regplot(x = 'sepal length', y = 'target', data = df)
plt.ylim(0,)
# Out:
# (0, 4.149265509091255)

# %%
df.describe(include = 'all')
# Out:
#         sepal length  sepal width  petal length  petal width       target
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width       target
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from sklearn.preprocessing import scale
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
df_iris_x = df.loc[:, features]
df_iris_x.head()
scaled = pd.DataFrame(scale(df_iris_x), columns = df_iris_x.columns)

# %%
df_iris_y = df.loc[:, 'target']

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)

principalComponents = pca.fit_transform(df_iris_x)

principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)
finalDf
# Out:
#      principal component 1  principal component 2          target
# 0                -2.684207               0.326607     Iris-setosa
# 1                -2.715391              -0.169557     Iris-setosa
# 2                -2.889820              -0.137346     Iris-setosa
# 3                -2.746437              -0.311124     Iris-setosa
# 4                -2.728593               0.333925     Iris-setosa
# 5                -2.279897               0.747783     Iris-setosa
# 6                -2.820891              -0.082105     Iris-setosa
# 7                -2.626482               0.170405     Iris-setosa
# 8                -2.887959              -0.570798     Iris-setosa
# 9                -2.673845              -0.106692     Iris-setosa
# 10               -2.506527               0.651935     Iris-setosa
# 11               -2.613143               0.021521     Iris-setosa
# 12               -2.787434              -0.227740     Iris-setosa
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.92461621, 0.05301557])

# %%
from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')
# Out:
# C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function fetch_mldata is deprecated; fetch_mldata was deprecated in version 0.20 and will be removed in version 0.22
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\15Z970-GA5BK\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function mldata_filename is deprecated; mldata_filename was deprecated in version 0.20 and will be removed in version 0.22
#   warnings.warn(msg, category=DeprecationWarning)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-32-3ba7b9c02a3b> in <module>
#       1 from sklearn.datasets import fetch_mldata
# ----> 2 mnist = fetch_mldata('MNIST original')
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py in wrapped(*args, **kwargs)
#      76         def wrapped(*args, **kwargs):
# ...

# %%
from sklearn.model_selection import train_test_split
# test_size: what proportion of original data is used for test set
train_img, test_img, train_lbl, test_lbl = train_test_split( mnist.data, mnist.target, test_size=1/7.0, random_state=0)
