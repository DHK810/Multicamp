# %%
import pandas as pd
import os

os.chdir(r'C:\Users\15Z970-GA5BK\Desktop\multicampus0724\project\VOC\scrapy_amazon\amazon_crawl')

# %%
data = pd.read_csv('output.csv')

# %% [markdown]
# # non값 전처리

# %%
data['review'] = data['review'].fillna('a')
data[data['review'] == 'a']
# Out:
#        Unnamed: 0                       asin  \
# 7314         7314   B01D0PKF0Q?pageNumber=41
# 9131         9131   B01D93Z89W?pageNumber=67
# 9289         9289   B01D93Z89W?pageNumber=70
# 9910         9910   B01D93Z89W?pageNumber=82
# 10934       10934  B01D93Z89W?pageNumber=110
# 17464        6006                 B01D0PKF0Q
# 20357        8899                 B01D93Z89W
# 20495        9037                 B01D93Z89W
# 20970        9512                 B01D93Z89W
# 22042       10584                 B01D93Z89W
# 29384        7026                 B01D0PKF0Q
# 31378        9020                 B01D93Z89W
# 31538        9180                 B01D93Z89W
# 32091        9733                 B01D93Z89W
# 33103       10745                 B01D93Z89W
# 39741        6174                 B01D0PKF0Q
# 42835        9268                 B01D93Z89W
# 43003        9436                 B01D93Z89W
# 43506        9939                 B01D93Z89W
# 44542       10975                 B01D93Z89W
# ...

# %%
data = data[data.review != 'a'][:10]

# %% [markdown]
# # 스코어 데이터 정리

# %%
data['score'] = data['score'].apply(lambda x : x.split()[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-07e9b829441b> in <module>
# ----> 1 data['score'] = data['score'].apply(lambda x : x.split()[0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-48-07e9b829441b> in <lambda>(x)
# ----> 1 data['score'] = data['score'].apply(lambda x : x.split()[0])
#
# AttributeError: 'float' object has no attribute 'split'

# %% [markdown]
# # str 타입이었던 score를 float으로 변경

# %%
float(data['score'][1])
# Out:
# 5.0

# %%
data.score = data.score.apply(lambda x: float(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
tfidf.fit(data['review'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
import numpy as np

data[data['score'] != 3]
data['posivitiy'] = np.where(data['score'] > 3, 1, 0)

# %%
data
# Out:
#    Unnamed: 0        asin item_model_no  \
# 0           0  B07S1HTSGH           NaN
# 1           1  B07S1HTSGH           NaN
# 2           2  B07S1HTSGH           NaN
# 3           3  B07S1HTSGH           NaN
# 4           4  B07S1HTSGH           NaN
# 5           5  B07S1HTSGH           NaN
# 6           6  B07S1HTSGH           NaN
# 7           7  B07S1HTSGH           NaN
# 8           8  B07S1HTSGH           NaN
# 9           9  B07S1HTSGH           NaN
#
#                                         product_name  \
# 0  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 1  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 2  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 3  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 4  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 5  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 6  Digital Camera with WiFi 24.0 MP Vlogging Came...
# 7  Digital Camera with WiFi 24.0 MP Vlogging Came...
# ...

# %%
cols = ['Unnamed: 0', 'asin', 'item_model_no', 'product_name', 'review_date']
data.drop(cols, axis = 1, inplace = True)
data
# Out:
#                                               review  score  \
# 0  I have a professional Nikon camera purchased s...    5.0
# 1  I like this camera but it was not what i expec...    5.0
# 2  Now is a good time to travel.I'm a novice phot...    5.0
# 3  I'm not sure if it was just the camera that I ...    3.0
# 4  Looks good. Ok for taking our holiday snaps an...    5.0
# 5  Poor instructions,No clear way to turn off vid...    2.0
# 6  This camera is bought for a birthday gift for ...    5.0
# 7  I was actually surprised about this camera. Yo...    5.0
# 8  I very like it, user friendly, easy operation,...    5.0
# 9  It is small，compact camera with required funct...    5.0
#
#                 user  posivitiy
# 0           Arsenals          1
# 1  Samira Alshaibani          1
# 2    Vargas Laurence          1
# 3              Diane          0
# 4        shawn mayun          1
# 5      Her Babsiness          0
# 6        lilygallego          1
# 7            Brandon          1
# ...

# %%
data.review[0]
# Out:
# 'I have a professional Nikon camera purchased several years ago but it’s too heavy for me. I am so glad I found this inexpensive camera on Amazon and it fits perfectly into my purse.The most fun part is the flip screen, taking selfie is much more easier. The pictures came out very clear and very real The battery capacity is about 3 hours. I will recommend it to my friend.'
