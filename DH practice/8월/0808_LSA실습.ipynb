# %%
#import modules
import os.path
from gensim import corpora
from gensim.models import LsiModel
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

# %% [markdown]
# # 실습 데이터 doc_ls

# %%
doc_ls = ['바나나 사과 포도 포도',
'사과 포도',
'포도 바나나',
'짜장면 짬뽕 탕수욕',
'볶음밥 탕수욕',
'짜장면 짬뽕',
'라면 스시',
'스시',
'가츠동 스시 소바',
'된장찌개 김치찌개 김치',
'김치 된장',
'비빔밥 김치'
]

# %% [markdown]
# # 아마존 리뷰 데이터

# %%
import pandas as pd
print(os.getcwd())
os.chdir(r'C:\\Users\15Z970-GA5BK\\Desktop\\multicampus0724\\project\\VOC\scrapy_amazon\\amazon_crawl')

data = pd.read_csv('output.csv')
# Out:
# C:\Users\15Z970-GA5BK\Desktop\multicampus0724\DH practice\8월

# %%
data = data[data['item_model_no'] == 'Nikon-Full-Frame-Mirrorless-Camera']

# %%
data['review'] = data['review'].fillna('a')

# %%
data = data.reset_index()

# %%
data
# Out:
#      index  Unnamed: 0                     asin  \
# 0     3892        3892               B07GPRSYG8
# 1     3902        3902               B07GPRSYG8
# 2     3909        3909               B07GPRSYG8
# 3     3911        3911               B07GPRSYG8
# 4     3912        3912               B07GPRSYG8
# 5     3913        3913               B07GPRSYG8
# 6     3914        3914               B07GPRSYG8
# 7     3915        3915               B07GPRSYG8
# 8     3916        3916               B07GPRSYG8
# 9     3917        3917               B07GPRSYG8
# 10    4004        4004  B07GPRSYG8?pageNumber=2
# 11    4008        4008  B07GPRSYG8?pageNumber=2
# 12    4009        4009  B07GPRSYG8?pageNumber=2
# 13    4013        4013  B07GPRSYG8?pageNumber=2
# 14    4014        4014  B07GPRSYG8?pageNumber=2
# 15    4016        4016  B07GPRSYG8?pageNumber=2
# 16    4017        4017  B07GPRSYG8?pageNumber=2
# 17    4019        4019  B07GPRSYG8?pageNumber=2
# 18    4020        4020  B07GPRSYG8?pageNumber=2
# 19    4021        4021  B07GPRSYG8?pageNumber=2
# 20    4145        4145  B07GPRSYG8?pageNumber=3
# 21    4149        4149  B07GPRSYG8?pageNumber=3
# 22    4153        4153  B07GPRSYG8?pageNumber=3
# 23    4159        4159  B07GPRSYG8?pageNumber=3
# 24    4166        4166  B07GPRSYG8?pageNumber=3
# 25    4179        4179  B07GPRSYG8?pageNumber=3
# 26    4180        4180  B07GPRSYG8?pageNumber=3
# 27    4196        4196  B07GPRSYG8?pageNumber=3
# 28    4197        4197  B07GPRSYG8?pageNumber=3
# 29    4215        4215  B07GPRSYG8?pageNumber=3
# ..     ...         ...                      ...
# 418  99048        1911               B07GPRSYG8
# 419  99049        1912               B07GPRSYG8
# 420  99050        1913               B07GPRSYG8
# 421  99051        1914               B07GPRSYG8
# 422  99192        2055               B07GPRSYG8
# 423  99193        2056               B07GPRSYG8
# 424  99194        2057               B07GPRSYG8
# 425  99195        2058               B07GPRSYG8
# 426  99196        2059               B07GPRSYG8
# 427  99197        2060               B07GPRSYG8
# 428  99198        2061               B07GPRSYG8
# 429  99199        2062               B07GPRSYG8
# 430  99200        2063               B07GPRSYG8
# 431  99201        2064               B07GPRSYG8
# 432  99339        2202               B07GPRSYG8
# 433  99340        2203               B07GPRSYG8
# 434  99341        2204               B07GPRSYG8
# 435  99343        2206               B07GPRSYG8
# 436  99344        2207               B07GPRSYG8
# 437  99345        2208               B07GPRSYG8
# 438  99350        2213               B07GPRSYG8
# 439  99351        2214               B07GPRSYG8
# 440  99352        2215               B07GPRSYG8
# 441  99353        2216               B07GPRSYG8
# 442  99505        2368               B07GPRSYG8
# 443  99506        2369               B07GPRSYG8
# 444  99507        2370               B07GPRSYG8
# 445  99508        2371               B07GPRSYG8
# 446  99509        2372               B07GPRSYG8
# 447  99510        2373               B07GPRSYG8
#
#                           item_model_no  \
# 0    Nikon-Full-Frame-Mirrorless-Camera
# 1    Nikon-Full-Frame-Mirrorless-Camera
# 2    Nikon-Full-Frame-Mirrorless-Camera
# 3    Nikon-Full-Frame-Mirrorless-Camera
# 4    Nikon-Full-Frame-Mirrorless-Camera
# 5    Nikon-Full-Frame-Mirrorless-Camera
# 6    Nikon-Full-Frame-Mirrorless-Camera
# 7    Nikon-Full-Frame-Mirrorless-Camera
# 8    Nikon-Full-Frame-Mirrorless-Camera
# 9    Nikon-Full-Frame-Mirrorless-Camera
# 10   Nikon-Full-Frame-Mirrorless-Camera
# 11   Nikon-Full-Frame-Mirrorless-Camera
# 12   Nikon-Full-Frame-Mirrorless-Camera
# 13   Nikon-Full-Frame-Mirrorless-Camera
# 14   Nikon-Full-Frame-Mirrorless-Camera
# 15   Nikon-Full-Frame-Mirrorless-Camera
# 16   Nikon-Full-Frame-Mirrorless-Camera
# 17   Nikon-Full-Frame-Mirrorless-Camera
# 18   Nikon-Full-Frame-Mirrorless-Camera
# 19   Nikon-Full-Frame-Mirrorless-Camera
# 20   Nikon-Full-Frame-Mirrorless-Camera
# 21   Nikon-Full-Frame-Mirrorless-Camera
# 22   Nikon-Full-Frame-Mirrorless-Camera
# 23   Nikon-Full-Frame-Mirrorless-Camera
# 24   Nikon-Full-Frame-Mirrorless-Camera
# 25   Nikon-Full-Frame-Mirrorless-Camera
# 26   Nikon-Full-Frame-Mirrorless-Camera
# 27   Nikon-Full-Frame-Mirrorless-Camera
# 28   Nikon-Full-Frame-Mirrorless-Camera
# 29   Nikon-Full-Frame-Mirrorless-Camera
# ..                                  ...
# 418  Nikon-Full-Frame-Mirrorless-Camera
# 419  Nikon-Full-Frame-Mirrorless-Camera
# 420  Nikon-Full-Frame-Mirrorless-Camera
# 421  Nikon-Full-Frame-Mirrorless-Camera
# 422  Nikon-Full-Frame-Mirrorless-Camera
# 423  Nikon-Full-Frame-Mirrorless-Camera
# 424  Nikon-Full-Frame-Mirrorless-Camera
# 425  Nikon-Full-Frame-Mirrorless-Camera
# 426  Nikon-Full-Frame-Mirrorless-Camera
# 427  Nikon-Full-Frame-Mirrorless-Camera
# 428  Nikon-Full-Frame-Mirrorless-Camera
# 429  Nikon-Full-Frame-Mirrorless-Camera
# 430  Nikon-Full-Frame-Mirrorless-Camera
# 431  Nikon-Full-Frame-Mirrorless-Camera
# 432  Nikon-Full-Frame-Mirrorless-Camera
# 433  Nikon-Full-Frame-Mirrorless-Camera
# 434  Nikon-Full-Frame-Mirrorless-Camera
# 435  Nikon-Full-Frame-Mirrorless-Camera
# 436  Nikon-Full-Frame-Mirrorless-Camera
# 437  Nikon-Full-Frame-Mirrorless-Camera
# 438  Nikon-Full-Frame-Mirrorless-Camera
# 439  Nikon-Full-Frame-Mirrorless-Camera
# 440  Nikon-Full-Frame-Mirrorless-Camera
# 441  Nikon-Full-Frame-Mirrorless-Camera
# 442  Nikon-Full-Frame-Mirrorless-Camera
# 443  Nikon-Full-Frame-Mirrorless-Camera
# 444  Nikon-Full-Frame-Mirrorless-Camera
# 445  Nikon-Full-Frame-Mirrorless-Camera
# 446  Nikon-Full-Frame-Mirrorless-Camera
# 447  Nikon-Full-Frame-Mirrorless-Camera
#
#                                    product_name  \
# 0    Nikon Z6 Full Frame Mirrorless Camera Body
# 1    Nikon Z6 Full Frame Mirrorless Camera Body
# 2    Nikon Z6 Full Frame Mirrorless Camera Body
# 3    Nikon Z6 Full Frame Mirrorless Camera Body
# 4    Nikon Z6 Full Frame Mirrorless Camera Body
# 5    Nikon Z6 Full Frame Mirrorless Camera Body
# 6    Nikon Z6 Full Frame Mirrorless Camera Body
# 7    Nikon Z6 Full Frame Mirrorless Camera Body
# 8    Nikon Z6 Full Frame Mirrorless Camera Body
# 9    Nikon Z6 Full Frame Mirrorless Camera Body
# 10   Nikon Z6 Full Frame Mirrorless Camera Body
# 11   Nikon Z6 Full Frame Mirrorless Camera Body
# 12   Nikon Z6 Full Frame Mirrorless Camera Body
# 13   Nikon Z6 Full Frame Mirrorless Camera Body
# 14   Nikon Z6 Full Frame Mirrorless Camera Body
# 15   Nikon Z6 Full Frame Mirrorless Camera Body
# 16   Nikon Z6 Full Frame Mirrorless Camera Body
# 17   Nikon Z6 Full Frame Mirrorless Camera Body
# 18   Nikon Z6 Full Frame Mirrorless Camera Body
# 19   Nikon Z6 Full Frame Mirrorless Camera Body
# 20   Nikon Z6 Full Frame Mirrorless Camera Body
# 21   Nikon Z6 Full Frame Mirrorless Camera Body
# 22   Nikon Z6 Full Frame Mirrorless Camera Body
# 23   Nikon Z6 Full Frame Mirrorless Camera Body
# 24   Nikon Z6 Full Frame Mirrorless Camera Body
# 25   Nikon Z6 Full Frame Mirrorless Camera Body
# 26   Nikon Z6 Full Frame Mirrorless Camera Body
# 27   Nikon Z6 Full Frame Mirrorless Camera Body
# 28   Nikon Z6 Full Frame Mirrorless Camera Body
# 29   Nikon Z6 Full Frame Mirrorless Camera Body
# ..                                          ...
# 418  Nikon Z6 Full Frame Mirrorless Camera Body
# 419  Nikon Z6 Full Frame Mirrorless Camera Body
# 420  Nikon Z6 Full Frame Mirrorless Camera Body
# 421  Nikon Z6 Full Frame Mirrorless Camera Body
# 422  Nikon Z6 Full Frame Mirrorless Camera Body
# 423  Nikon Z6 Full Frame Mirrorless Camera Body
# 424  Nikon Z6 Full Frame Mirrorless Camera Body
# 425  Nikon Z6 Full Frame Mirrorless Camera Body
# 426  Nikon Z6 Full Frame Mirrorless Camera Body
# 427  Nikon Z6 Full Frame Mirrorless Camera Body
# 428  Nikon Z6 Full Frame Mirrorless Camera Body
# 429  Nikon Z6 Full Frame Mirrorless Camera Body
# 430  Nikon Z6 Full Frame Mirrorless Camera Body
# 431  Nikon Z6 Full Frame Mirrorless Camera Body
# 432  Nikon Z6 Full Frame Mirrorless Camera Body
# 433  Nikon Z6 Full Frame Mirrorless Camera Body
# 434  Nikon Z6 Full Frame Mirrorless Camera Body
# 435  Nikon Z6 Full Frame Mirrorless Camera Body
# 436  Nikon Z6 Full Frame Mirrorless Camera Body
# 437  Nikon Z6 Full Frame Mirrorless Camera Body
# 438  Nikon Z6 Full Frame Mirrorless Camera Body
# 439  Nikon Z6 Full Frame Mirrorless Camera Body
# 440  Nikon Z6 Full Frame Mirrorless Camera Body
# 441  Nikon Z6 Full Frame Mirrorless Camera Body
# 442  Nikon Z6 Full Frame Mirrorless Camera Body
# 443  Nikon Z6 Full Frame Mirrorless Camera Body
# 444  Nikon Z6 Full Frame Mirrorless Camera Body
# 445  Nikon Z6 Full Frame Mirrorless Camera Body
# 446  Nikon Z6 Full Frame Mirrorless Camera Body
# 447  Nikon Z6 Full Frame Mirrorless Camera Body
#
#                                                 review        review_date  \
# 0    I'm a long-time Nikon user, going back to film...  November 22, 2018
# 1    I shoot the northern lights weekly and sometim...  December 14, 2018
# 2    These are my first impressions with the Nikon ...  November 23, 2018
# 3    I was hoping for this to weigh less than a typ...  December 22, 2018
# 4    Autofocus is terrible.,Reviewing images I can ...   January 12, 2019
# 5    I went from D5000, D600, Fujifilm X100S, X70 t...    January 7, 2019
# 6    My first hobbyist camera was the Nikon FE. Sin...  November 21, 2018
# 7    I'm a beginner photography enthusiast, and was...  December 20, 2018
# 8    I currently shoot several Nikon bodies so my e...   January 10, 2019
# 9    For the past 10 years I've been shooting Leica...    January 4, 2019
# 10   Pitched as a replacement for the D750; have on...   February 5, 2019
# 11   I've had this camera for about a month now and...    January 6, 2019
# 12   I have owned the Z 6 now for about six months....       May 28, 2019
# 13   Since it was mirrorless I assumed it would be ...    January 5, 2019
# 14   I love my Z6. It replaced a Fuji X-T2 that I s...     March 21, 2019
# 15   After buying one Z6 and using it on jobs and l...        May 9, 2019
# 16   I switched to this camera from a Nikon D 3 and...   January 10, 2019
# 17   his is EVERYTHING a Nikon has needed to be sin...   January 13, 2019
# 18   Bought the filmmakers kit from amazon... The M...       May 30, 2019
# 19   Bought the Z6 for filmmaking and it doesn't di...  February 14, 2019
# 20   Former Nikon N60 SLR and D200 DSLR owner, I ha...      June 27, 2019
# 21   Got this for my fiance's Christmas present and...      March 2, 2019
# 22   I'm a filmmaker, not a photographer so I don't...       June 5, 2019
# 23   XT1 type AF and yes high ISO is clean, if you ...  February 17, 2019
# 24   I ended up returning the camera, but I am very...   January 29, 2019
# 25   The camera performs as advertised, and there a...     March 14, 2019
# 26   Got it on time and it is working great. Still ...  December 22, 2018
# 27                      Didn't work. Had to return it.  February 10, 2019
# 28                                        Great camera  November 20, 2018
# 29   This is the best camera to get if you want to ...      March 5, 2019
# ..                                                 ...                ...
# 418  Got it on time and it is working great. Still ...  December 22, 2018
# 419                     Didn't work. Had to return it.  February 10, 2019
# 420                                       Great camera  November 20, 2018
# 421  This is the best camera to get if you want to ...      March 5, 2019
# 422  There should be a starter memory package inclu...      July 13, 2019
# 423  Purchased the 24-70 F/4 bundle, love everythin...      July 11, 2019
# 424  Everything you heard and then some! Nikon is c...      June 29, 2019
# 425  Very fun to use a touch screen and have video ...   December 2, 2018
# 426  NOTE: This is a review of the Nikon Z6 Filmmak...  February 26, 2019
# 427  For years I wanted a mirrorless camera, though...  December 15, 2018
# 428  I bought the Filmmaker's kit directly from Nik...     March 26, 2019
# 429  I placed an order of the Nikon Z6 with the 24-...  November 25, 2018
# 430  Beautiful camera, very well built, great AF an...  November 21, 2018
# 431  The Z6 with the FTZ adapter and 24-70 f4 S len...  November 27, 2018
# 432  Superb camera with outstanding low light perfo...  November 24, 2018
# 433  I was going back and forth and couldn't make u...      June 10, 2019
# 434  So this review is for those wondering how the ...     March 19, 2019
# 435  I AM MOVING FROM MY GOOD OLD D700 TO THIS NEW ...  November 27, 2018
# 436  Sold one of my D610s to get this camera. Have ...  February 14, 2019
# 437  I traded my Nikon D7000 for this camera. Resea...  February 17, 2019
# 438  It's the Beast and the Best mirrorless camera ...      July 24, 2019
# 439  This is the best mirrorless full frame camera ...      March 6, 2019
# 440  Finally upgrading to FX from the D5300 and am ...  December 31, 2018
# 441  I am an amateur photographer and have used Nik...       May 27, 2019
# 442  I was patiently waiting to upgrade my entry-le...  February 15, 2019
# 443  Such a great all around camera for photos and ...   January 10, 2019
# 444  Excellent camera.,For those that are intereste...      June 12, 2019
# 445  Absolute and utter garbage. I tried it for a w...       July 4, 2019
# 446  Image quality is amazing. Video is amazing. AF...      June 21, 2019
# 447  I've been shooting with a D5200 since 2013 and...   December 5, 2018
#
#                   score                               user
# 0    5.0 out of 5 stars                           J. C. M.
# 1    3.0 out of 5 stars                              Aaron
# 2    4.0 out of 5 stars                           undfined
# 3    2.0 out of 5 stars  Franwin Pharmacy Mineola Surgical
# 4    2.0 out of 5 stars                               ioji
# 5    2.0 out of 5 stars                                 DJ
# 6    5.0 out of 5 stars                              uncas
# 7    5.0 out of 5 stars                             Tony R
# 8    5.0 out of 5 stars                     Robert J Smith
# 9    4.0 out of 5 stars                          G. Morris
# 10   4.0 out of 5 stars                              S. W.
# 11   4.0 out of 5 stars                      Dave Thompson
# 12   5.0 out of 5 stars                            Spencer
# 13   2.0 out of 5 stars                    janice thompson
# 14   5.0 out of 5 stars                   Andy C., Chicago
# 15   5.0 out of 5 stars                                 Ed
# 16   5.0 out of 5 stars                        Al Lijewski
# 17   5.0 out of 5 stars                     ChrisKingPhoto
# 18   1.0 out of 5 stars                       Rick D Smith
# 19   5.0 out of 5 stars               brian keith schnaare
# 20   5.0 out of 5 stars                           James S.
# 21   5.0 out of 5 stars                   Melissa Beninger
# 22   5.0 out of 5 stars                        Robert Lane
# 23   1.0 out of 5 stars                          WowFactor
# 24   4.0 out of 5 stars                     james d morley
# 25   5.0 out of 5 stars                            Clayton
# 26   5.0 out of 5 stars                       Paul Peckham
# 27   1.0 out of 5 stars                            Charles
# 28   5.0 out of 5 stars                              Zac S
# 29   5.0 out of 5 stars                                Nic
# ..                  ...                                ...
# 418  5.0 out of 5 stars                       Paul Peckham
# 419  1.0 out of 5 stars                            Charles
# 420  5.0 out of 5 stars                              Zac S
# 421  5.0 out of 5 stars                                Nic
# 422  5.0 out of 5 stars                                  E
# 423  5.0 out of 5 stars                               NCEC
# 424  5.0 out of 5 stars                       Brady Taylor
# 425  4.0 out of 5 stars                            ®ichard
# 426  3.0 out of 5 stars                            David R
# 427  5.0 out of 5 stars                             Miller
# 428  4.0 out of 5 stars                        Peter Henry
# 429  5.0 out of 5 stars                          Gadgetman
# 430  5.0 out of 5 stars                       Elie Hobeika
# 431  5.0 out of 5 stars                  Marc R. Feldesman
# 432  5.0 out of 5 stars                    Amazon Customer
# 433  5.0 out of 5 stars                             Chinky
# 434  3.0 out of 5 stars                           AZ buyer
# 435  5.0 out of 5 stars                        Hing On Sun
# 436  5.0 out of 5 stars                                Jim
# 437  5.0 out of 5 stars                   moutain explorer
# 438  5.0 out of 5 stars                    Sadhana Chhetri
# 439  5.0 out of 5 stars                             Austin
# 440  5.0 out of 5 stars                              J & P
# 441  5.0 out of 5 stars                   Thomas Rawlinson
# 442  5.0 out of 5 stars                               DJ R
# 443  5.0 out of 5 stars                            Cameron
# 444  5.0 out of 5 stars                   Vincent Terenzio
# 445  1.0 out of 5 stars                                joe
# 446  5.0 out of 5 stars                        Robert Munk
# 447  5.0 out of 5 stars                          S. Holder
#
# [448 rows x 9 columns]

# %%
list_ = []

for i in range(0, 10):
    list_.append(data.review[i])

# %%
def preprocess_data(doc_set):
    """
    Input  : docuemnt list
    Purpose: preprocess text (tokenize, removing stopwords, and stemming)
    Output : preprocessed text
    """
    # initialize regex tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    # create English stop words list
    en_stop = set(stopwords.words('english'))
    # Create p_stemmer of class PorterStemmer
    p_stemmer = PorterStemmer()
    # list for tokenized documents in loop
    texts = []
    # loop through document list
    for i in doc_set:
        # clean and tokenize document string
        raw = i.lower()
        tokens = tokenizer.tokenize(raw)
        # remove stop words from tokens
        stopped_tokens = [i for i in tokens if not i in en_stop]
        # stem tokens
        stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
        # add tokens to list
        texts.append(stemmed_tokens)
        
    return texts

# %%
def prepare_corpus(doc_clean):
    """
    Input  : clean document
    Purpose: create term dictionary of our courpus and Converting list of documents (corpus) into Document Term Matrix
    Output : term dictionary and Document Term Matrix
    """
    # Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
    dictionary = corpora.Dictionary(doc_clean)
    
    # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
    
    # generate LDA model
    return dictionary,doc_term_matrix

# %%
def create_gensim_lsa_model(doc_clean,number_of_topics,words):
    """
    Input  : clean document, number of topics and number of words associated with each topic
    Purpose: create LSA model using gensim
    Output : return LSA model
    """
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    # generate LSA model
    lsamodel = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
    print(lsamodel.print_topics(num_topics=number_of_topics, num_words=words))
    return lsamodel

# %%
def compute_coherence_values(dictionary, doc_term_matrix, doc_clean, stop, start=2, step=3):
    """
    Input   : dictionary : Gensim dictionary
              corpus : Gensim corpus
              texts : List of input texts
              stop : Max num of topics
    purpose : Compute c_v coherence for various number of topics
    Output  : model_list : List of LSA topic models
              coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, stop, step):
        # generate LSA model
        model = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=doc_clean, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

# %%
def create_gensim_lsa_model(doc_clean,number_of_topics,words):
    """
    Input  : clean document, number of topics and number of words associated with each topic
    Purpose: create LSA model using gensim
    Output : return LSA model
    """
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    # generate LSA model
    lsamodel = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
    print(lsamodel.print_topics(num_topics=number_of_topics, num_words=words))
    return lsamodel

# %%
# LSA Model
number_of_topics=4
words=3

clean_text=preprocess_data(doc_ls)
model=create_gensim_lsa_model(clean_text,number_of_topics,words)
# Out:
# [(0, '0.816*"포도" + 0.408*"바나나" + 0.408*"사과"'), (1, '-0.612*"짬뽕" + -0.612*"짜장면" + -0.484*"탕수욕"'), (2, '-0.813*"김치" + -0.337*"김치찌개" + -0.337*"된장찌개"'), (3, '0.815*"스시" + 0.368*"가츠동" + 0.368*"소바"')]

# %%
ifidf_vec = TfidfVectorizer(use_idf = True, norm='12')
svd = TruncatedSVD(n_components=dim)
